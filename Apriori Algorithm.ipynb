# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('Groceries_dataset.csv')

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
grocery_df_date= df.groupby('Date').agg({'itemDescription':','.join})

# %%
grocery_df_date
# Out:
#                                               itemDescription
# Date
# 01-01-2014  cleaner,sausage,tropical fruit,whole milk,citr...
# 01-01-2015  canned beer,frozen meals,butter,ham,citrus fru...
# 01-02-2014  other vegetables,pip fruit,frankfurter,sugar,o...
# 01-02-2015  whole milk,canned beer,bottled water,soda,whol...
# 01-03-2014  sausage,meat,sugar,sausage,bottled beer,whole ...
# ...                                                       ...
# 31-07-2015  vinegar,chicken,root vegetables,chicken,sausag...
# 31-08-2014  pork,other vegetables,beef,whole milk,hygiene ...
# 31-08-2015  brown bread,frankfurter,chicken,citrus fruit,b...
# 31-10-2014  yogurt,frankfurter,other vegetables,salty snac...
# 31-10-2015  chicken,canned beer,frozen vegetables,beef,can...
#
# [728 rows x 1 columns]

# %%
grocery_df_date.head()
# Out:
#                                               itemDescription
# Date
# 01-01-2014  cleaner,sausage,tropical fruit,whole milk,citr...
# 01-01-2015  canned beer,frozen meals,butter,ham,citrus fru...
# 01-02-2014  other vegetables,pip fruit,frankfurter,sugar,o...
# 01-02-2015  whole milk,canned beer,bottled water,soda,whol...
# 01-03-2014  sausage,meat,sugar,sausage,bottled beer,whole ...

# %%
#associative rule according to gouping by items sold on date

# %%
grocery_df_date['itemDescription'] = grocery_df_date['itemDescription'].str.split(',')

# %%
transactions=[]
for i in range(0,len(grocery_df_date)):
    transactions.append(grocery_df_date['itemDescription'][i])

# %%
transactions
# Out:
# [['cleaner',
#   'sausage',
#   'tropical fruit',
#   'whole milk',
#   'citrus fruit',
#   'onions',
#   'other vegetables',
#   'berries',
#   'hamburger meat',
#   'hamburger meat',
#   'other vegetables',
#   'hamburger meat',
#   'bottled water',
#   'butter',
#   'yogurt',
#   'yogurt',
#   'waffles',
#   'soda',
#   'sliced cheese',
#   'curd',
#   'specialty chocolate',
#   'shopping bags',
#   'bottled water',
#   'other vegetables',
#   'flower (seeds)',
#   'coffee',
#   'whipped/sour cream',
#   'yogurt',
#   'whipped/sour cream',
#   'frozen potato products',
#   'candles',
#   'yogurt',
#   'bottled beer',
#   'Instant food products',
#   'frozen vegetables',
#   'shopping bags',
#   'frozen vegetables',
#   'whole milk',
#   'brown bread',
#   'bottled water',
#   'soda',
#   'frozen vegetables',
#   'Instant food products',
#   'domestic eggs',
#   'waffles',
#   'dishes',
#   'chocolate',
#   'bottled water'],
#  ['canned beer',
#   'frozen meals',
#   'butter',
#   'ham',
#   'citrus fruit',
#   'tropical fruit',
#   'dessert',
#   'whole milk',
#   'tropical fruit',
#   'frankfurter',
#   'butter',
#   'sausage',
#   'citrus fruit',
#   'canned beer',
#   'pork',
#   'beef',
#   'white bread',
#   'meat',
#   'whipped/sour cream',
#   'sausage',
#   'tropical fruit',
#   'hamburger meat',
#   'other vegetables',
#   'pastry',
#   'brown bread',
#   'whole milk',
#   'turkey',
#   'soda',
#   'canned beer',
#   'pip fruit',
#   'citrus fruit',
#   'tropical fruit',
#   'bottled beer',
#   'soda',
#   'margarine',
#   'pickled vegetables',
#   'pastry',
#   'brown bread',
#   'salt',
#   'whole milk',
#   'spread cheese',
#   'bottled water',
#   'curd',
#   'fruit/vegetable juice',
#   'pot plants',
#   'dishes',
#   'chocolate',
#   'salty snack'],
#  ['other vegetables',
#   'pip fruit',
#   'frankfurter',
#   'sugar',
#   'other vegetables',
#   'frozen vegetables',
#   'beef',
#   'waffles',
#   'beef',
#   'meat',
#   'root vegetables',
#   'pastry',
#   'butter',
#   'brown bread',
#   'root vegetables',
#   'frozen vegetables',
#   'ice cream',
#   'soda',
#   'rolls/buns',
#   'brown bread',
#   'chicken',
#   'citrus fruit',
#   'soda',
#   'white bread',
#   'frozen fish',
#   'sparkling wine',
#   'cream cheese ',
#   'whole milk',
#   'tropical fruit',
#   'fruit/vegetable juice',
#   'yogurt',
#   'condensed milk',
#   'curd',
#   'soft cheese',
#   'canned beer',
#   'candy',
#   'yogurt',
#   'bottled beer',
#   'dessert',
#   'yogurt',
#   'shopping bags',
#   'whipped/sour cream',
#   'butter milk',
#   'butter',
#   'pickled vegetables',
#   'other vegetables',
#   'fruit/vegetable juice',
#   'frozen dessert',
#   'hard cheese',
#   'waffles',
#   'frozen vegetables',
#   'soda',
#   'oil',
#   'soda',
#   'bottled beer',
#   'frozen meals',
#   'napkins',
#   'misc. beverages',
#   'bottled water',
#   'brown bread',
#   'specialty bar',
#   'dishes'],
#  ['whole milk',
#   'canned beer',
#   'bottled water',
#   'soda',
#   'whole milk',
#   'other vegetables',
#   'whole milk',
#   'canned beer',
#   'pip fruit',
#   'tropical fruit',
#   'domestic eggs',
#   'other vegetables',
#   'frozen meals',
#   'pork',
#   'canned beer',
#   'sausage',
#   'whole milk',
#   'ham',
#   'pork',
#   'canned beer',
#   'soda',
#   'root vegetables',
#   'sausage',
#   'beef',
#   'yogurt',
#   'yogurt',
#   'whole milk',
#   'brown bread',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'yogurt',
#   'other vegetables',
#   'sliced cheese',
#   'liver loaf',
#   'other vegetables',
#   'tropical fruit',
#   'long life bakery product',
#   'whole milk',
#   'frozen vegetables',
#   'beef',
#   'yogurt',
#   'pork',
#   'waffles',
#   'tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'pip fruit',
#   'UHT-milk',
#   'whole milk',
#   'yogurt',
#   'cream cheese ',
#   'processed cheese',
#   'canned fish',
#   'oil',
#   'flower (seeds)',
#   'white bread',
#   'newspapers',
#   'oil',
#   'sugar',
#   'artif. sweetener'],
#  ['sausage',
#   'meat',
#   'sugar',
#   'sausage',
#   'bottled beer',
#   'whole milk',
#   'other vegetables',
#   'root vegetables',
#   'fruit/vegetable juice',
#   'soda',
#   'pastry',
#   'canned beer',
#   'yogurt',
#   'butter milk',
#   'spices',
#   'soda',
#   'root vegetables',
#   'other vegetables',
#   'berries',
#   'soda',
#   'margarine',
#   'domestic eggs',
#   'processed cheese',
#   'white bread',
#   'hard cheese',
#   'canned beer',
#   'salty snack',
#   'other vegetables',
#   'spices',
#   'bottled water',
#   'liqueur',
#   'shopping bags',
#   'shopping bags',
#   'newspapers',
#   'cat food',
#   'margarine',
#   'soda',
#   'brown bread',
#   'pastry',
#   'whipped/sour cream',
#   'waffles',
#   'mustard',
#   'preservation products',
#   'curd',
#   'pickled vegetables',
#   'soda',
#   'margarine',
#   'seasonal products',
#   'specialty chocolate',
#   'brown bread',
#   'soups',
#   'whipped/sour cream',
#   'bottled water',
#   'whipped/sour cream'],
#  ['bottled water',
#   'tropical fruit',
#   'whole milk',
#   'brown bread',
#   'citrus fruit',
#   'tropical fruit',
#   'beef',
#   'coffee',
#   'whole milk',
#   'beef',
#   'beverages',
#   'frankfurter',
#   'newspapers',
#   'beverages',
#   'sausage',
#   'coffee',
#   'citrus fruit',
#   'sausage',
#   'whole milk',
#   'frankfurter',
#   'condensed milk',
#   'root vegetables',
#   'coffee',
#   'whole milk',
#   'berries',
#   'frankfurter',
#   'sausage',
#   'whipped/sour cream',
#   'frankfurter',
#   'frankfurter',
#   'beverages',
#   'bottled beer',
#   'frozen meals',
#   'hamburger meat',
#   'tropical fruit',
#   'soda',
#   'light bulbs',
#   'shopping bags',
#   'other vegetables',
#   'soft cheese',
#   'whole milk',
#   'butter',
#   'whipped/sour cream',
#   'whole milk',
#   'chocolate marshmallow',
#   'pip fruit',
#   'whole milk',
#   'other vegetables',
#   'long life bakery product',
#   'brown bread',
#   'pastry',
#   'bottled beer',
#   'frozen fruits',
#   'bottled beer',
#   'rolls/buns',
#   'soda',
#   'frozen vegetables',
#   'tropical fruit',
#   'napkins',
#   'margarine',
#   'shopping bags',
#   'pickled vegetables',
#   'margarine',
#   'sugar',
#   'fruit/vegetable juice',
#   'brown bread',
#   'soda',
#   'detergent',
#   'light bulbs',
#   'dish cleaner',
#   'domestic eggs',
#   'chewing gum',
#   'curd',
#   'soda',
#   'chewing gum',
#   'organic products'],
#  ['frankfurter',
#   'frankfurter',
#   'pastry',
#   'salty snack',
#   'bottled beer',
#   'male cosmetics',
#   'margarine',
#   'cat food',
#   'rolls/buns',
#   'rolls/buns',
#   'salty snack',
#   'dessert',
#   'whole milk',
#   'bottled beer',
#   'rolls/buns',
#   'tropical fruit',
#   'whole milk',
#   'cat food',
#   'root vegetables',
#   'rolls/buns',
#   'beef',
#   'whipped/sour cream',
#   'canned fish',
#   'root vegetables',
#   'sausage',
#   'whole milk',
#   'prosecco',
#   'white bread',
#   'salty snack',
#   'berries',
#   'oil',
#   'domestic eggs',
#   'soda',
#   'bottled beer',
#   'whole milk',
#   'frozen meals',
#   'frozen fish',
#   'soda',
#   'fruit/vegetable juice',
#   'yogurt',
#   'whole milk',
#   'domestic eggs',
#   'yogurt',
#   'soda',
#   'flour',
#   'house keeping products',
#   'yogurt',
#   'coffee',
#   'domestic eggs',
#   'rolls/buns',
#   'seasonal products',
#   'brown bread',
#   'brown bread',
#   'margarine',
#   'rolls/buns',
#   'bottled beer',
#   'canned fish',
#   'white bread',
#   'bottled beer',
#   'long life bakery product',
#   'pastry',
#   'white bread',
#   'hair spray',
#   'male cosmetics'],
#  ['tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'meat',
#   'hamburger meat',
#   'whole milk',
#   'other vegetables',
#   'whole milk',
#   'finished products',
#   'whole milk',
#   'soda',
#   'whole milk',
#   'frankfurter',
#   'root vegetables',
#   'whole milk',
#   'soda',
#   'citrus fruit',
#   'pasta',
#   'whole milk',
#   'other vegetables',
#   'frankfurter',
#   'fruit/vegetable juice',
#   'UHT-milk',
#   'beef',
#   'tropical fruit',
#   'specialty chocolate',
#   'curd',
#   'citrus fruit',
#   'chewing gum',
#   'frankfurter',
#   'soda',
#   'frankfurter',
#   'sausage',
#   'sausage',
#   'beef',
#   'hamburger meat',
#   'newspapers',
#   'yogurt',
#   'sausage',
#   'whole milk',
#   'meat',
#   'whole milk',
#   'whole milk',
#   'specialty chocolate',
#   'bottled water',
#   'chocolate',
#   'whole milk',
#   'whole milk',
#   'pip fruit',
#   'whole milk',
#   'beverages',
#   'pip fruit',
#   'pet care',
#   'butter milk',
#   'rolls/buns',
#   'dessert',
#   'yogurt',
#   'hard cheese',
#   'citrus fruit',
#   'rolls/buns',
#   'rolls/buns',
#   'berries',
#   'cocoa drinks',
#   'brown bread',
#   'whole milk',
#   'other vegetables',
#   'pot plants',
#   'curd',
#   'coffee',
#   'semi-finished bread',
#   'yogurt',
#   'vinegar',
#   'whole milk',
#   'bottled water',
#   'rolls/buns',
#   'frozen vegetables',
#   'coffee',
#   'canned vegetables',
#   'whipped/sour cream',
#   'dishes',
#   'frozen vegetables',
#   'newspapers',
#   'whipped/sour cream'],
#  ['sausage',
#   'root vegetables',
#   'whipped/sour cream',
#   'whole milk',
#   'beef',
#   'specialty bar',
#   'rolls/buns',
#   'other vegetables',
#   'finished products',
#   'soda',
#   'other vegetables',
#   'tropical fruit',
#   'seasonal products',
#   'tropical fruit',
#   'hamburger meat',
#   'dessert',
#   'sliced cheese',
#   'butter',
#   'red/blush wine',
#   'napkins',
#   'spices',
#   'soda',
#   'packaged fruit/vegetables',
#   'cooking chocolate',
#   'other vegetables',
#   'whole milk',
#   'semi-finished bread',
#   'white bread',
#   'other vegetables',
#   'pastry',
#   'rolls/buns',
#   'fruit/vegetable juice',
#   'cream cheese ',
#   'flour',
#   'dish cleaner',
#   'cream cheese ',
#   'napkins',
#   'shopping bags',
#   'red/blush wine',
#   'bottled water',
#   'semi-finished bread',
#   'cream cheese ',
#   'cling film/bags',
#   'rolls/buns'],
#  ['whole milk',
#   'other vegetables',
#   'meat',
#   'pastry',
#   'pip fruit',
#   'sausage',
#   'liquor',
#   'shopping bags',
#   'pip fruit',
#   'other vegetables',
#   'photo/film',
#   'tropical fruit',
#   'root vegetables',
#   'mayonnaise',
#   'pork',
#   'chicken',
#   'meat',
#   'whole milk',
#   'rolls/buns',
#   'bottled water',
#   'frankfurter',
#   'whole milk',
#   'pastry',
#   'beef',
#   'hamburger meat',
#   'tropical fruit',
#   'pork',
#   'chewing gum',
#   'frankfurter',
#   'cookware',
#   'soda',
#   'tropical fruit',
#   'whole milk',
#   'soda',
#   'bottled beer',
#   'whole milk',
#   'sweet spreads',
#   'cling film/bags',
#   'rolls/buns',
#   'tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'pastry',
#   'fruit/vegetable juice',
#   'sliced cheese',
#   'root vegetables',
#   'butter',
#   'tropical fruit',
#   'root vegetables',
#   'bottled beer',
#   'chocolate',
#   'brown bread',
#   'soda',
#   'beverages',
#   'soft cheese',
#   'yogurt',
#   'curd',
#   'oil',
#   'mayonnaise',
#   'newspapers',
#   'soda',
#   'cat food',
#   'detergent',
#   'white wine',
#   'cereals',
#   'waffles'],
#  ['citrus fruit',
#   'pork',
#   'napkins',
#   'oil',
#   'bottled beer',
#   'bottled water',
#   'tropical fruit',
#   'whole milk',
#   'whole milk',
#   'candy',
#   'berries',
#   'newspapers',
#   'other vegetables',
#   'canned vegetables',
#   'UHT-milk',
#   'newspapers',
#   'frozen meals',
#   'whipped/sour cream',
#   'softener',
#   'sugar',
#   'domestic eggs',
#   'brown bread',
#   'whipped/sour cream',
#   'butter milk',
#   'seasonal products',
#   'processed cheese',
#   'domestic eggs',
#   'shopping bags',
#   'soda',
#   'canned vegetables',
#   'bottled water',
#   'roll products '],
#  ['packaged fruit/vegetables',
#   'hamburger meat',
#   'tropical fruit',
#   'domestic eggs',
#   'chocolate',
#   'yogurt',
#   'whole milk',
#   'frankfurter',
#   'pork',
#   'margarine',
#   'soda',
#   'tropical fruit',
#   'tropical fruit',
#   'rolls/buns',
#   'root vegetables',
#   'sliced cheese',
#   'rolls/buns',
#   'pip fruit',
#   'ham',
#   'herbs',
#   'other vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'other vegetables',
#   'specialty bar',
#   'grapes',
#   'chewing gum',
#   'pip fruit',
#   'other vegetables',
#   'brown bread',
#   'instant coffee'],
#  ['other vegetables',
#   'ham',
#   'specialty cheese',
#   'sliced cheese',
#   'canned beer',
#   'liquor',
#   'nut snack',
#   'cream cheese ',
#   'soda',
#   'root vegetables',
#   'dessert',
#   'butter',
#   'pip fruit',
#   'tropical fruit',
#   'yogurt',
#   'onions',
#   'newspapers',
#   'frozen fish',
#   'hygiene articles',
#   'whole milk',
#   'misc. beverages',
#   'bottled water',
#   'ice cream',
#   'soda',
#   'mayonnaise',
#   'root vegetables',
#   'dish cleaner',
#   'processed cheese',
#   'rice',
#   'rolls/buns',
#   'fruit/vegetable juice',
#   'specialty bar',
#   'jam'],
#  ['sausage',
#   'other vegetables',
#   'meat',
#   'beef',
#   'bottled beer',
#   'whole milk',
#   'frozen fish',
#   'pork',
#   'bottled water',
#   'pork',
#   'whole milk',
#   'butter',
#   'pork',
#   'other vegetables',
#   'frankfurter',
#   'other vegetables',
#   'whole milk',
#   'dessert',
#   'misc. beverages',
#   'butter',
#   'whole milk',
#   'whole milk',
#   'citrus fruit',
#   'whole milk',
#   'frankfurter',
#   'misc. beverages',
#   'yogurt',
#   'other vegetables',
#   'bottled water',
#   'other vegetables',
#   'soda',
#   'specialty cheese',
#   'rolls/buns',
#   'whole milk',
#   'coffee',
#   'bottled beer',
#   'whole milk',
#   'spread cheese',
#   'zwieback',
#   'curd',
#   'pip fruit',
#   'soda',
#   'bottled beer',
#   'soft cheese',
#   'grapes',
#   'specialty bar',
#   'hard cheese',
#   'other vegetables',
#   'domestic eggs',
#   'brown bread',
#   'bottled water',
#   'chewing gum',
#   'chocolate',
#   'sugar',
#   'soda',
#   'bottled beer',
#   'yogurt'],
#  ['pip fruit',
#   'frozen meals',
#   'root vegetables',
#   'whole milk',
#   'other vegetables',
#   'yogurt',
#   'pet care',
#   'curd',
#   'onions',
#   'citrus fruit',
#   'whole milk',
#   'whole milk',
#   'specialty cheese',
#   'semi-finished bread',
#   'chicken',
#   'pork',
#   'soda',
#   'syrup',
#   'soda',
#   'margarine',
#   'canned beer',
#   'newspapers',
#   'margarine',
#   'frozen meals',
#   'newspapers',
#   'cream cheese ',
#   'sugar',
#   'chocolate',
#   'dessert',
#   'root vegetables',
#   'brown bread',
#   'newspapers',
#   'domestic eggs',
#   'cereals',
#   'seasonal products',
#   'whole milk',
#   'semi-finished bread',
#   'nut snack',
#   'sliced cheese',
#   'hard cheese',
#   'dog food',
#   'chocolate marshmallow',
#   'mustard',
#   'yogurt',
#   'rolls/buns',
#   'female sanitary products',
#   'shopping bags',
#   'sweet spreads',
#   'dish cleaner'],
#  ['beef',
#   'sausage',
#   'citrus fruit',
#   'beef',
#   'ham',
#   'bottled beer',
#   'other vegetables',
#   'rolls/buns',
#   'sausage',
#   'citrus fruit',
#   'frankfurter',
#   'canned beer',
#   'frankfurter',
#   'chicken',
#   'rolls/buns',
#   'root vegetables',
#   'yogurt',
#   'tropical fruit',
#   'ham',
#   'sausage',
#   'berries',
#   'yogurt',
#   'beverages',
#   'coffee',
#   'ham',
#   'soda',
#   'whole milk',
#   'specialty chocolate',
#   'whole milk',
#   'condensed milk',
#   'frozen vegetables',
#   'herbs',
#   'tropical fruit',
#   'misc. beverages',
#   'brown bread',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'whole milk',
#   'dish cleaner',
#   'whole milk',
#   'pastry',
#   'red/blush wine',
#   'curd',
#   'sliced cheese',
#   'other vegetables',
#   'chocolate',
#   'citrus fruit',
#   'whole milk',
#   'canned beer',
#   'root vegetables',
#   'pastry',
#   'other vegetables',
#   'napkins',
#   'onions',
#   'rolls/buns',
#   'rolls/buns',
#   'whole milk',
#   'fruit/vegetable juice',
#   'white bread',
#   'butter',
#   'pickled vegetables',
#   'hard cheese',
#   'semi-finished bread',
#   'misc. beverages',
#   'frozen vegetables',
#   'bottled water',
#   'kitchen towels',
#   'brown bread',
#   'rolls/buns',
#   'margarine'],
#  ['white wine',
#   'root vegetables',
#   'sausage',
#   'herbs',
#   'misc. beverages',
#   'candy',
#   'bottled water',
#   'sugar',
#   'pasta',
#   'packaged fruit/vegetables',
#   'ham',
#   'soda',
#   'tropical fruit',
#   'root vegetables',
#   'turkey',
#   'rolls/buns',
#   'pip fruit',
#   'pip fruit',
#   'whole milk',
#   'hygiene articles',
#   'brown bread',
#   'specialty chocolate',
#   'coffee',
#   'UHT-milk',
#   'soda',
#   'grapes',
#   'shopping bags',
#   'tropical fruit',
#   'cream cheese ',
#   'bottled water',
#   'cream cheese ',
#   'popcorn',
#   'whole milk',
#   'pastry',
#   'waffles',
#   'butter',
#   'frozen dessert',
#   'frozen vegetables',
#   'butter',
#   'whipped/sour cream',
#   'canned fish',
#   'skin care',
#   'dessert',
#   'domestic eggs',
#   'salty snack',
#   'salty snack',
#   'soda',
#   'spread cheese',
#   'UHT-milk',
#   'canned vegetables',
#   'frozen vegetables',
#   'bottled beer',
#   'cream cheese ',
#   'butter',
#   'whipped/sour cream',
#   'yogurt',
#   'rolls/buns',
#   'shopping bags',
#   'soups',
#   'newspapers',
#   'beverages',
#   'specialty chocolate',
#   'cling film/bags',
#   'dental care'],
#  ['oil',
#   'soda',
#   'rolls/buns',
#   'ice cream',
#   'misc. beverages',
#   'pip fruit',
#   'turkey',
#   'hamburger meat',
#   'specialty chocolate',
#   'tropical fruit',
#   'other vegetables',
#   'whipped/sour cream',
#   'cat food',
#   'shopping bags',
#   'yogurt',
#   'liquor (appetizer)',
#   'domestic eggs',
#   'whole milk',
#   'soda',
#   'specialty chocolate',
#   'soft cheese',
#   'rolls/buns'],
#  ['rolls/buns',
#   'liquor (appetizer)',
#   'pastry',
#   'finished products',
#   'tropical fruit',
#   'meat',
#   'long life bakery product',
#   'citrus fruit',
#   'curd',
#   'rolls/buns',
#   'other vegetables',
#   'specialty bar',
#   'brown bread',
#   'sliced cheese',
#   'whole milk',
#   'meat',
#   'citrus fruit',
#   'berries',
#   'salty snack',
#   'beef',
#   'white wine',
#   'yogurt',
#   'misc. beverages',
#   'candy',
#   'syrup',
#   'dessert',
#   'dessert',
#   'whole milk',
#   'bottled beer',
#   'yogurt',
#   'long life bakery product',
#   'other vegetables',
#   'domestic eggs',
#   'candles',
#   'processed cheese',
#   'sugar',
#   'root vegetables',
#   'tropical fruit',
#   'other vegetables',
#   'beverages',
#   'napkins',
#   'flour',
#   'rolls/buns',
#   'rolls/buns',
#   'misc. beverages',
#   'bottled water',
#   'yogurt',
#   'dessert',
#   'pastry',
#   'sugar',
#   'rolls/buns',
#   'whole milk',
#   'long life bakery product',
#   'yogurt',
#   'soda',
#   'candles',
#   'bottled beer',
#   'napkins',
#   'whisky',
#   'napkins'],
#  ['citrus fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'root vegetables',
#   'other vegetables',
#   'ice cream',
#   'sausage',
#   'rolls/buns',
#   'semi-finished bread',
#   'whole milk',
#   'sausage',
#   'pastry',
#   'sausage',
#   'chicken',
#   'tropical fruit',
#   'bottled beer',
#   'turkey',
#   'other vegetables',
#   'tropical fruit',
#   'tropical fruit',
#   'whole milk',
#   'yogurt',
#   'misc. beverages',
#   'canned fish',
#   'tropical fruit',
#   'tropical fruit',
#   'red/blush wine',
#   'processed cheese',
#   'rolls/buns',
#   'cream cheese ',
#   'seasonal products',
#   'spices',
#   'yogurt',
#   'soda',
#   'citrus fruit',
#   'cake bar',
#   'newspapers',
#   'tropical fruit',
#   'root vegetables',
#   'sugar',
#   'cream cheese ',
#   'coffee',
#   'fruit/vegetable juice',
#   'female sanitary products',
#   'shopping bags',
#   'waffles',
#   'salty snack',
#   'rolls/buns',
#   'soda',
#   'domestic eggs',
#   'mayonnaise',
#   'rolls/buns'],
#  ['sausage',
#   'whole milk',
#   'other vegetables',
#   'whole milk',
#   'whole milk',
#   'soda',
#   'rolls/buns',
#   'other vegetables',
#   'other vegetables',
#   'soda',
#   'fruit/vegetable juice',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'domestic eggs',
#   'misc. beverages',
#   'fruit/vegetable juice',
#   'detergent',
#   'other vegetables',
#   'rolls/buns',
#   'beverages',
#   'other vegetables',
#   'chewing gum',
#   'soups',
#   'bottled water',
#   'margarine',
#   'whole milk',
#   'ice cream',
#   'semi-finished bread',
#   'shopping bags',
#   'soda',
#   'soda',
#   'cream cheese '],
#  ['other vegetables',
#   'berries',
#   'bottled water',
#   'whole milk',
#   'yogurt',
#   'whole milk',
#   'canned beer',
#   'sausage',
#   'yogurt',
#   'tropical fruit',
#   'whole milk',
#   'whole milk',
#   'cat food',
#   'ham',
#   'onions',
#   'onions',
#   'detergent',
#   'other vegetables',
#   'whole milk',
#   'curd cheese',
#   'canned beer',
#   'other vegetables',
#   'butter',
#   'other vegetables',
#   'soda',
#   'shopping bags',
#   'bottled beer',
#   'pip fruit',
#   'seasonal products',
#   'other vegetables',
#   'soda',
#   'soda',
#   'root vegetables',
#   'soda',
#   'sliced cheese',
#   'other vegetables',
#   'liquor (appetizer)',
#   'coffee',
#   'salty snack',
#   'specialty chocolate',
#   'curd',
#   'pastry',
#   'dishes',
#   'newspapers',
#   'curd',
#   'sugar',
#   'detergent',
#   'nut snack',
#   'zwieback',
#   'canned beer'],
#  ['beef',
#   'berries',
#   'sausage',
#   'meat',
#   'root vegetables',
#   'curd',
#   'whole milk',
#   'frozen vegetables',
#   'whole milk',
#   'shopping bags',
#   'newspapers',
#   'pip fruit',
#   'soda',
#   'rolls/buns',
#   'pork',
#   'whole milk',
#   'whole milk',
#   'candy',
#   'pip fruit',
#   'newspapers',
#   'chocolate',
#   'whipped/sour cream',
#   'yogurt',
#   'white wine',
#   'butter',
#   'specialty bar',
#   'other vegetables',
#   'bottled water',
#   'bottled beer',
#   'brown bread',
#   'oil',
#   'long life bakery product',
#   'other vegetables',
#   'frozen potato products',
#   'other vegetables',
#   'sugar',
#   'brown bread',
#   'specialty bar',
#   'hard cheese',
#   'flour'],
#  ['chicken',
#   'ice cream',
#   'sparkling wine',
#   'whole milk',
#   'canned beer',
#   'berries',
#   'whole milk',
#   'sausage',
#   'whole milk',
#   'sausage',
#   'tropical fruit',
#   'sausage',
#   'chicken',
#   'chicken',
#   'butter',
#   'frankfurter',
#   'whole milk',
#   'whipped/sour cream',
#   'tropical fruit',
#   'frankfurter',
#   'root vegetables',
#   'chicken',
#   'tropical fruit',
#   'coffee',
#   'other vegetables',
#   'root vegetables',
#   'butter',
#   'oil',
#   'root vegetables',
#   'bottled water',
#   'coffee',
#   'other vegetables',
#   'frozen vegetables',
#   'rolls/buns',
#   'rolls/buns',
#   'whole milk',
#   'dessert',
#   'mayonnaise',
#   'pip fruit',
#   'pip fruit',
#   'whole milk',
#   'long life bakery product',
#   'curd',
#   'yogurt',
#   'curd cheese',
#   'hamburger meat',
#   'herbs',
#   'white bread',
#   'napkins',
#   'fruit/vegetable juice',
#   'seasonal products',
#   'yogurt',
#   'cream cheese ',
#   'sugar'],
#  ['beef',
#   'frankfurter',
#   'hamburger meat',
#   'soda',
#   'UHT-milk',
#   'root vegetables',
#   'rolls/buns',
#   'rolls/buns',
#   'long life bakery product',
#   'curd',
#   'brown bread',
#   'root vegetables',
#   'beef',
#   'whole milk',
#   'fruit/vegetable juice',
#   'rolls/buns',
#   'tropical fruit',
#   'semi-finished bread',
#   'rolls/buns',
#   'canned beer',
#   'fruit/vegetable juice',
#   'margarine',
#   'other vegetables',
#   'butter',
#   'other vegetables',
#   'hard cheese',
#   'domestic eggs',
#   'whole milk',
#   'soap',
#   'newspapers',
#   'curd',
#   'dessert',
#   'whole milk',
#   'pot plants',
#   'fruit/vegetable juice',
#   'frozen vegetables',
#   'candy',
#   'white bread',
#   'grapes',
#   'salty snack',
#   'margarine',
#   'chewing gum',
#   'whipped/sour cream',
#   'roll products ',
#   'coffee',
#   'waffles',
#   'rolls/buns',
#   'whole milk',
#   'roll products ',
#   'newspapers',
#   'yogurt',
#   'soda',
#   'dishes',
#   'sauces',
#   'newspapers'],
#  ['citrus fruit',
#   'frankfurter',
#   'rolls/buns',
#   'citrus fruit',
#   'photo/film',
#   'white wine',
#   'pork',
#   'sausage',
#   'pip fruit',
#   'flower soil/fertilizer',
#   'other vegetables',
#   'chicken',
#   'sausage',
#   'pip fruit',
#   'pork',
#   'bottled beer',
#   'whole milk',
#   'mayonnaise',
#   'shopping bags',
#   'domestic eggs',
#   'newspapers',
#   'other vegetables',
#   'bottled water',
#   'brown bread',
#   'yogurt',
#   'canned beer',
#   'tropical fruit',
#   'cat food',
#   'whole milk',
#   'whole milk',
#   'margarine',
#   'cocoa drinks',
#   'cat food',
#   'specialty chocolate',
#   'shopping bags'],
#  ['sausage',
#   'domestic eggs',
#   'hard cheese',
#   'tropical fruit',
#   'curd',
#   'baking powder',
#   'beef',
#   'hard cheese',
#   'meat',
#   'white wine',
#   'whole milk',
#   'canned beer',
#   'rolls/buns',
#   'whole milk',
#   'tropical fruit',
#   'rolls/buns',
#   'dessert',
#   'whipped/sour cream',
#   'coffee',
#   'bottled beer',
#   'canned beer',
#   'root vegetables',
#   'shopping bags',
#   'sugar',
#   'pip fruit',
#   'frozen potato products',
#   'cream cheese ',
#   'yogurt',
#   'brown bread',
#   'soda',
#   'frozen vegetables',
#   'whipped/sour cream',
#   'frozen potato products',
#   'curd',
#   'fruit/vegetable juice',
#   'other vegetables',
#   'canned beer',
#   'cake bar',
#   'yogurt',
#   'soda',
#   'whole milk',
#   'napkins',
#   'frozen vegetables',
#   'newspapers'],
#  ['sausage',
#   'citrus fruit',
#   'UHT-milk',
#   'frankfurter',
#   'ham',
#   'dessert',
#   'pip fruit',
#   'onions',
#   'ham',
#   'ham',
#   'hamburger meat',
#   'sausage',
#   'hamburger meat',
#   'pork',
#   'berries',
#   'pip fruit',
#   'ice cream',
#   'bottled water',
#   'pickled vegetables',
#   'other vegetables',
#   'butter',
#   'rolls/buns',
#   'detergent',
#   'specialty bar',
#   'cleaner',
#   'whipped/sour cream',
#   'yogurt',
#   'vinegar',
#   'soft cheese',
#   'yogurt',
#   'dishes',
#   'specialty bar'],
#  ['chicken',
#   'frankfurter',
#   'butter milk',
#   'whole milk',
#   'hamburger meat',
#   'beef',
#   'domestic eggs',
#   'yogurt',
#   'rolls/buns',
#   'bottled beer',
#   'cling film/bags',
#   'whole milk',
#   'whipped/sour cream',
#   'root vegetables',
#   'root vegetables',
#   'whole milk',
#   'whole milk',
#   'whole milk',
#   'other vegetables',
#   'pip fruit',
#   'rolls/buns',
#   'butter',
#   'pastry',
#   'rolls/buns',
#   'butter',
#   'other vegetables',
#   'pip fruit',
#   'coffee',
#   'shopping bags',
#   'curd cheese',
#   'frozen vegetables',
#   'domestic eggs',
#   'curd',
#   'newspapers',
#   'coffee',
#   'salty snack',
#   'fruit/vegetable juice',
#   'whole milk',
#   'other vegetables',
#   'butter milk',
#   'pasta',
#   'brandy',
#   'whipped/sour cream',
#   'butter',
#   'cat food',
#   'seasonal products',
#   'specialty chocolate',
#   'soda',
#   'shopping bags',
#   'frozen dessert',
#   'oil',
#   'rolls/buns',
#   'soda',
#   'shopping bags',
#   'candy',
#   'fruit/vegetable juice',
#   'soups',
#   'other vegetables',
#   'fruit/vegetable juice',
#   'sliced cheese',
#   'domestic eggs',
#   'pastry',
#   'bottled water',
#   'Instant food products'],
#  ['whole milk',
#   'beef',
#   'citrus fruit',
#   'brandy',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'rolls/buns',
#   'pip fruit',
#   'frankfurter',
#   'chicken',
#   'whole milk',
#   'chocolate',
#   'whole milk',
#   'dessert',
#   'pastry',
#   'citrus fruit',
#   'tropical fruit',
#   'canned beer',
#   'waffles',
#   'root vegetables',
#   'sausage',
#   'sausage',
#   'sausage',
#   'male cosmetics',
#   'sugar',
#   'whole milk',
#   'bottled beer',
#   'rolls/buns',
#   'grapes',
#   'condensed milk',
#   'other vegetables',
#   'root vegetables',
#   'frozen fish',
#   'tropical fruit',
#   'dessert',
#   'rolls/buns',
#   'yogurt',
#   'onions',
#   'other vegetables',
#   'bottled beer',
#   'dishes',
#   'shopping bags',
#   'sugar',
#   'root vegetables',
#   'whipped/sour cream',
#   'pastry',
#   'rolls/buns',
#   'whole milk',
#   'sugar',
#   'UHT-milk',
#   'other vegetables',
#   'dental care',
#   'white bread',
#   'root vegetables',
#   'pastry',
#   'long life bakery product',
#   'dessert',
#   'processed cheese',
#   'pip fruit',
#   'root vegetables',
#   'dog food',
#   'yogurt',
#   'shopping bags',
#   'house keeping products',
#   'whole milk',
#   'specialty chocolate',
#   'detergent',
#   'brown bread',
#   'rice',
#   'whole milk',
#   'frozen vegetables',
#   'frozen vegetables',
#   'sliced cheese'],
#  ['pork',
#   'whole milk',
#   'rolls/buns',
#   'white bread',
#   'other vegetables',
#   'bottled water',
#   'berries',
#   'white bread',
#   'other vegetables',
#   'whole milk',
#   'sweet spreads',
#   'dessert',
#   'other vegetables',
#   'pip fruit',
#   'tropical fruit',
#   'whole milk',
#   'yogurt',
#   'margarine',
#   'pip fruit',
#   'misc. beverages',
#   'dessert',
#   'ice cream',
#   'margarine',
#   'cocoa drinks',
#   'other vegetables',
#   'bottled water',
#   'rolls/buns',
#   'cream cheese ',
#   'pastry',
#   'canned fish',
#   'other vegetables',
#   'bottled water',
#   'coffee',
#   'pot plants',
#   'bottled beer',
#   'spread cheese',
#   'other vegetables',
#   'curd',
#   'chewing gum',
#   'sugar',
#   'soft cheese',
#   'processed cheese',
#   'beverages',
#   'pastry',
#   'misc. beverages',
#   'soft cheese',
#   'soda',
#   'butter milk',
#   'waffles',
#   'brown bread',
#   'white bread',
#   'yogurt',
#   'soda',
#   'frozen meals',
#   'bottled beer',
#   'oil',
#   'salty snack',
#   'fruit/vegetable juice',
#   'napkins',
#   'white wine',
#   'white bread',
#   'soda',
#   'whole milk'],
#  ['sausage',
#   'frankfurter',
#   'oil',
#   'sausage',
#   'whole milk',
#   'whole milk',
#   'salty snack',
#   'soft cheese',
#   'canned beer',
#   'tropical fruit',
#   'hamburger meat',
#   'whole milk',
#   'chicken',
#   'bottled water',
#   'sausage',
#   'zwieback',
#   'rolls/buns',
#   'yogurt',
#   'butter',
#   'frankfurter',
#   'tropical fruit',
#   'detergent',
#   'yogurt',
#   'onions',
#   'other vegetables',
#   'chocolate',
#   'newspapers',
#   'pastry',
#   'semi-finished bread',
#   'rolls/buns',
#   'root vegetables',
#   'yogurt',
#   'pip fruit',
#   'other vegetables',
#   'rolls/buns',
#   'canned beer',
#   'shopping bags',
#   'root vegetables',
#   'newspapers',
#   'fruit/vegetable juice',
#   'domestic eggs',
#   'semi-finished bread',
#   'kitchen towels',
#   'hygiene articles',
#   'whipped/sour cream',
#   'Instant food products',
#   'frozen dessert',
#   'rolls/buns'],
#  ['pork',
#   'pip fruit',
#   'tropical fruit',
#   'root vegetables',
#   'tropical fruit',
#   'bottled water',
#   'other vegetables',
#   'whole milk',
#   'other vegetables',
#   'other vegetables',
#   'citrus fruit',
#   'pickled vegetables',
#   'citrus fruit',
#   'dessert',
#   'rolls/buns',
#   'frozen vegetables',
#   'butter',
#   'yogurt',
#   'grapes',
#   'tropical fruit',
#   'butter',
#   'soda',
#   'pip fruit',
#   'rolls/buns',
#   'cream cheese ',
#   'softener',
#   'citrus fruit',
#   'soft cheese',
#   'chocolate',
#   'rolls/buns',
#   'dessert',
#   'dishes',
#   'pastry',
#   'cream cheese ',
#   'flower (seeds)',
#   'flower (seeds)',
#   'cat food',
#   'whole milk',
#   'sliced cheese',
#   'canned beer',
#   'other vegetables',
#   'cling film/bags',
#   'rolls/buns',
#   'margarine',
#   'bottled beer',
#   'rolls/buns',
#   'soda',
#   'rolls/buns',
#   'yogurt',
#   'newspapers',
#   'dishes',
#   'chocolate',
#   'dish cleaner',
#   'beverages',
#   'whipped/sour cream',
#   'shopping bags',
#   'chocolate',
#   'curd cheese'],
#  ['soda',
#   'coffee',
#   'chicken',
#   'ice cream',
#   'onions',
#   'sausage',
#   'sausage',
#   'root vegetables',
#   'whole milk',
#   'pasta',
#   'whole milk',
#   'rolls/buns',
#   'frankfurter',
#   'yogurt',
#   'sausage',
#   'frozen meals',
#   'soda',
#   'whole milk',
#   'liver loaf',
#   'whole milk',
#   'frankfurter',
#   'whipped/sour cream',
#   'frankfurter',
#   'misc. beverages',
#   'tropical fruit',
#   'onions',
#   'spread cheese',
#   'beef',
#   'brown bread',
#   'beef',
#   'root vegetables',
#   'pip fruit',
#   'hamburger meat',
#   'long life bakery product',
#   'curd',
#   'root vegetables',
#   'soda',
#   'chicken',
#   'soda',
#   'curd',
#   'other vegetables',
#   'tropical fruit',
#   'bottled water',
#   'tropical fruit',
#   'rolls/buns',
#   'citrus fruit',
#   'rolls/buns',
#   'white bread',
#   'whipped/sour cream',
#   'other vegetables',
#   'beverages',
#   'bottled water',
#   'flour',
#   'rolls/buns',
#   'fruit/vegetable juice',
#   'beverages',
#   'curd',
#   'meat spreads',
#   'beef',
#   'frozen vegetables',
#   'sweet spreads',
#   'long life bakery product',
#   'specialty bar',
#   'fruit/vegetable juice',
#   'whipped/sour cream',
#   'specialty cheese',
#   'whipped/sour cream',
#   'curd',
#   'bottled water',
#   'frozen vegetables',
#   'whipped/sour cream',
#   'rolls/buns',
#   'pudding powder',
#   'dish cleaner',
#   'cat food'],
#  ['frankfurter',
#   'whole milk',
#   'citrus fruit',
#   'coffee',
#   'chewing gum',
#   'citrus fruit',
#   'grapes',
#   'whipped/sour cream',
#   'specialty bar',
#   'white bread',
#   'specialty chocolate',
#   'herbs',
#   'canned beer',
#   'pork',
#   'cat food',
#   'cat food',
#   'curd cheese',
#   'beef',
#   'domestic eggs',
#   'whole milk',
#   'chocolate',
#   'UHT-milk',
#   'other vegetables',
#   'rolls/buns',
#   'cream cheese ',
#   'butter',
#   'rolls/buns',
#   'chocolate marshmallow',
#   'yogurt',
#   'dog food',
#   'specialty bar',
#   'onions',
#   'newspapers',
#   'other vegetables',
#   'other vegetables',
#   'soda',
#   'butter',
#   'pastry',
#   'margarine',
#   'tropical fruit',
#   'sauces',
#   'domestic eggs',
#   'kitchen towels',
#   'coffee',
#   'mayonnaise',
#   'brandy',
#   'yogurt',
#   'newspapers',
#   'dessert',
#   'yogurt',
#   'yogurt',
#   'dishes',
#   'rolls/buns',
#   'pastry',
#   'white bread',
#   'margarine',
#   'shopping bags',
#   'dessert',
#   'domestic eggs',
#   'pastry',
#   'specialty vegetables',
#   'cream cheese ',
#   'newspapers'],
#  ['dessert',
#   'beef',
#   'sausage',
#   'napkins',
#   'hamburger meat',
#   'soda',
#   'sausage',
#   'pork',
#   'whole milk',
#   'finished products',
#   'root vegetables',
#   'onions',
#   'meat',
#   'margarine',
#   'canned beer',
#   'soda',
#   'rolls/buns',
#   'rolls/buns',
#   'yogurt',
#   'pastry',
#   'citrus fruit',
#   'coffee',
#   'flower (seeds)',
#   'frozen vegetables',
#   'white bread',
#   'frozen vegetables',
#   'rolls/buns',
#   'pasta',
#   'cat food',
#   'oil',
#   'tropical fruit',
#   'canned beer',
#   'soda',
#   'cream cheese ',
#   'soda',
#   'flour',
#   'shopping bags',
#   'frozen vegetables',
#   'shopping bags',
#   'UHT-milk',
#   'cocoa drinks',
#   'fruit/vegetable juice',
#   'flower (seeds)',
#   'cream cheese ',
#   'misc. beverages'],
#  ['yogurt',
#   'shopping bags',
#   'whole milk',
#   'white wine',
#   'whole milk',
#   'pastry',
#   'ham',
#   'other vegetables',
#   'rolls/buns',
#   'other vegetables',
#   'chewing gum',
#   'whole milk',
#   'long life bakery product',
#   'frozen meals',
#   'brown bread',
#   'tropical fruit',
#   'whole milk',
#   'other vegetables',
#   'soda',
#   'bottled water',
#   'berries',
#   'onions',
#   'root vegetables',
#   'zwieback',
#   'pip fruit',
#   'misc. beverages',
#   'root vegetables',
#   'rolls/buns',
#   'yogurt',
#   'domestic eggs',
#   'whole milk',
#   'male cosmetics',
#   'brown bread',
#   'pastry',
#   'rolls/buns',
#   'frozen potato products',
#   'root vegetables',
#   'frozen dessert',
#   'waffles',
#   'flour',
#   'brown bread',
#   'chocolate',
#   'chocolate marshmallow',
#   'coffee',
#   'baking powder',
#   'rolls/buns',
#   'pastry',
#   'butter',
#   'soda',
#   'white wine',
#   'soft cheese',
#   'pastry',
#   'bottled water',
#   'hard cheese',
#   'curd',
#   'bottled water',
#   'soda',
#   'UHT-milk',
#   'white bread',
#   'specialty chocolate',
#   'napkins',
#   'newspapers',
#   'sugar'],
#  ['sausage',
#   'berries',
#   'specialty bar',
#   'frankfurter',
#   'chicken',
#   'whipped/sour cream',
#   'frankfurter',
#   'frozen meals',
#   'root vegetables',
#   'root vegetables',
#   'shopping bags',
#   'chocolate',
#   'canned beer',
#   'herbs',
#   'coffee',
#   'pastry',
#   'coffee',
#   'ham',
#   'misc. beverages',
#   'liver loaf',
#   'sliced cheese',
#   'berries',
#   'white bread',
#   'curd',
#   'tropical fruit',
#   'fruit/vegetable juice',
#   'yogurt',
#   'rolls/buns',
#   'whole milk',
#   'white bread',
#   'soda',
#   'snack products',
#   'bottled water',
#   'newspapers',
#   'whole milk',
#   'tropical fruit',
#   'shopping bags',
#   'onions',
#   'rolls/buns',
#   'other vegetables',
#   'domestic eggs',
#   'oil',
#   'flower (seeds)',
#   'brown bread',
#   'rolls/buns',
#   'shopping bags',
#   'frozen dessert',
#   'cream cheese '],
#  ['soda',
#   'UHT-milk',
#   'frankfurter',
#   'other vegetables',
#   'pork',
#   'white wine',
#   'dessert',
#   'whole milk',
#   'bottled water',
#   'bottled water',
#   'vinegar',
#   'candy',
#   'ice cream',
#   'tropical fruit',
#   'whole milk',
#   'tropical fruit',
#   'pet care',
#   'bottled beer',
#   'beef',
#   'sauces',
#   'yogurt',
#   'specialty chocolate',
#   'beverages',
#   'citrus fruit',
#   'candy',
#   'shopping bags',
#   'hard cheese',
#   'waffles',
#   'rolls/buns',
#   'domestic eggs',
#   'other vegetables',
#   'newspapers',
#   'bottled beer',
#   'shopping bags',
#   'whole milk',
#   'domestic eggs',
#   'beef',
#   'shopping bags',
#   'bottled beer',
#   'rolls/buns',
#   'photo/film',
#   'canned beer',
#   'frozen vegetables',
#   'misc. beverages',
#   'whipped/sour cream',
#   'brown bread',
#   'shopping bags',
#   'cat food',
#   'canned beer',
#   'cream cheese ',
#   'whole milk',
#   'brown bread',
#   'roll products ',
#   'yogurt',
#   'fruit/vegetable juice',
#   'brown bread',
#   'shopping bags',
#   'other vegetables',
#   'frozen vegetables',
#   'canned beer',
#   'curd',
#   'soft cheese',
#   'butter',
#   'fruit/vegetable juice',
#   'waffles',
#   'waffles',
#   'bottled beer'],
#  ['beef',
#   'citrus fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'tropical fruit',
#   'sausage',
#   'sausage',
#   'other vegetables',
#   'whipped/sour cream',
#   'chicken',
#   'pork',
#   'sausage',
#   'pork',
#   'UHT-milk',
#   'rolls/buns',
#   'UHT-milk',
#   'chocolate',
#   'ice cream',
#   'citrus fruit',
#   'root vegetables',
#   'yogurt',
#   'other vegetables',
#   'tropical fruit',
#   'condensed milk',
#   'seasonal products',
#   'whole milk',
#   'root vegetables',
#   'other vegetables',
#   'butter',
#   'berries',
#   'semi-finished bread',
#   'curd',
#   'frozen vegetables',
#   'pip fruit',
#   'rolls/buns',
#   'whole milk',
#   'bottled beer',
#   'coffee',
#   'condensed milk',
#   'pip fruit',
#   'other vegetables',
#   'newspapers',
#   'rolls/buns',
#   'candy',
#   'beef',
#   'male cosmetics',
#   'pet care',
#   'rolls/buns',
#   'other vegetables',
#   'other vegetables',
#   'white bread',
#   'domestic eggs',
#   'butter milk',
#   'oil',
#   'candy',
#   'specialty vegetables',
#   'canned beer',
#   'coffee',
#   'white bread',
#   'soda'],
#  ['rolls/buns',
#   'meat',
#   'citrus fruit',
#   'citrus fruit',
#   'brown bread',
#   'pastry',
#   'pastry',
#   'cereals',
#   'berries',
#   'pastry',
#   'other vegetables',
#   'beef',
#   'curd',
#   'specialty bar',
#   'pip fruit',
#   'frozen dessert',
#   'other vegetables',
#   'margarine',
#   'rolls/buns',
#   'beef',
#   'ham',
#   'tropical fruit',
#   'citrus fruit',
#   'rolls/buns',
#   'citrus fruit',
#   'grapes',
#   'butter milk',
#   'soda',
#   'bottled water',
#   'yogurt',
#   'rolls/buns',
#   'pasta',
#   'rolls/buns',
#   'curd',
#   'yogurt',
#   'detergent',
#   'sparkling wine',
#   'condensed milk',
#   'roll products ',
#   'skin care',
#   'newspapers',
#   'soft cheese',
#   'whipped/sour cream',
#   'whole milk',
#   'bottled water',
#   'dessert',
#   'flower (seeds)',
#   'rolls/buns',
#   'root vegetables',
#   'sweet spreads',
#   'pastry',
#   'candy',
#   'Instant food products',
#   'bottled water',
#   'mayonnaise',
#   'frozen fish',
#   'soda',
#   'dishes',
#   'chewing gum',
#   'dental care',
#   'domestic eggs',
#   'waffles',
#   'domestic eggs'],
#  ['chocolate',
#   'yogurt',
#   'sugar',
#   'whole milk',
#   'whole milk',
#   'hamburger meat',
#   'root vegetables',
#   'UHT-milk',
#   'whole milk',
#   'sausage',
#   'canned vegetables',
#   'pip fruit',
#   'dessert',
#   'processed cheese',
#   'herbs',
#   'sausage',
#   'bottled beer',
#   'other vegetables',
#   'frankfurter',
#   'canned beer',
#   'domestic eggs',
#   'other vegetables',
#   'pastry',
#   'yogurt',
#   'sliced cheese',
#   'fruit/vegetable juice',
#   'root vegetables',
#   'tropical fruit',
#   'newspapers',
#   'misc. beverages',
#   'other vegetables',
#   'baking powder',
#   'oil',
#   'other vegetables',
#   'hygiene articles',
#   'candles',
#   'fruit/vegetable juice',
#   'newspapers',
#   'frozen vegetables',
#   'oil',
#   'pip fruit',
#   'margarine',
#   'coffee',
#   'whole milk',
#   'bottled water',
#   'coffee',
#   'whipped/sour cream',
#   'cream cheese ',
#   'canned vegetables',
#   'newspapers',
#   'brown bread',
#   'frozen dessert'],
#  ['pastry',
#   'whole milk',
#   'meat',
#   'whole milk',
#   'root vegetables',
#   'other vegetables',
#   'chocolate',
#   'whole milk',
#   'meat',
#   'yogurt',
#   'soda',
#   'root vegetables',
#   'rolls/buns',
#   'female sanitary products',
#   'pastry',
#   'shopping bags',
#   'frozen dessert',
#   'whole milk',
#   'margarine',
#   'butter',
#   'yogurt',
#   'dessert',
#   'yogurt',
#   'frozen potato products',
#   'curd',
#   'yogurt',
#   'beverages',
#   'soda',
#   'domestic eggs',
#   'bottled water',
#   'margarine',
#   'canned beer',
#   'long life bakery product',
#   'bottled water',
#   'pastry',
#   'specialty bar',
#   'domestic eggs',
#   'sugar',
#   'pot plants',
#   'bathroom cleaner',
#   'brown bread',
#   'sweet spreads'],
#  ['bottled water',
#   'yogurt',
#   'domestic eggs',
#   'bottled beer',
#   'yogurt',
#   'napkins',
#   'white bread',
#   'pip fruit',
#   'whole milk',
#   'hamburger meat',
#   'pork',
#   'bottled water',
#   'meat',
#   'beverages',
#   'canned beer',
#   'UHT-milk',
#   'dessert',
#   'dessert',
#   'seasonal products',
#   'pastry',
#   'mustard',
#   'domestic eggs',
#   'margarine',
#   'bottled water',
#   'root vegetables',
#   'brown bread',
#   'chocolate',
#   'roll products ',
#   'soda',
#   'bottled beer'],
#  ['salty snack',
#   'rolls/buns',
#   'whole milk',
#   'root vegetables',
#   'whole milk',
#   'bottled water',
#   'other vegetables',
#   'whole milk',
#   'waffles',
#   'meat',
#   'turkey',
#   'bottled water',
#   'yogurt',
#   'hard cheese',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'bottled water',
#   'berries',
#   'hard cheese',
#   'curd',
#   'whipped/sour cream',
#   'bottled beer',
#   'whipped/sour cream',
#   'whipped/sour cream',
#   'rolls/buns',
#   'rolls/buns',
#   'candy',
#   'sparkling wine',
#   'citrus fruit',
#   'whipped/sour cream',
#   'hamburger meat',
#   'butter',
#   'shopping bags',
#   'rolls/buns',
#   'pet care',
#   'grapes',
#   'processed cheese',
#   'white wine',
#   'butter',
#   'yogurt',
#   'canned beer',
#   'cling film/bags',
#   'frozen potato products',
#   'sugar',
#   'soda',
#   'waffles',
#   'pastry',
#   'fruit/vegetable juice',
#   'specialty bar',
#   'soda'],
#  ['frankfurter',
#   'other vegetables',
#   'bottled beer',
#   'whole milk',
#   'brown bread',
#   'rolls/buns',
#   'soda',
#   'other vegetables',
#   'chicken',
#   'canned beer',
#   'pork',
#   'rolls/buns',
#   'whole milk',
#   'misc. beverages',
#   'oil',
#   'tropical fruit',
#   'rolls/buns',
#   'tropical fruit',
#   'beef',
#   'pip fruit',
#   'whole milk',
#   'domestic eggs',
#   'chocolate',
#   'frozen vegetables',
#   'frozen vegetables',
#   'other vegetables',
#   'bottled beer',
#   'bottled beer',
#   'soda',
#   'dessert',
#   'tropical fruit',
#   'rolls/buns',
#   'beverages',
#   'butter',
#   'whole milk',
#   'brown bread',
#   'other vegetables',
#   'UHT-milk',
#   'cake bar',
#   'rolls/buns',
#   'specialty fat',
#   'red/blush wine',
#   'soda',
#   'butter',
#   'roll products ',
#   'newspapers',
#   'curd',
#   'rolls/buns'],
#  ['ice cream',
#   'oil',
#   'pip fruit',
#   'rolls/buns',
#   'shopping bags',
#   'cake bar',
#   'canned beer',
#   'cream cheese ',
#   'pastry',
#   'fruit/vegetable juice',
#   'whole milk',
#   'soft cheese',
#   'whole milk',
#   'canned beer',
#   'berries',
#   'sausage',
#   'curd',
#   'soda',
#   'whole milk',
#   'bottled water',
#   'sausage',
#   'whole milk',
#   'fruit/vegetable juice',
#   'white wine',
#   'whole milk',
#   'hard cheese',
#   'pastry',
#   'frozen dessert',
#   'brown bread',
#   'bottled beer',
#   'whole milk',
#   'cat food',
#   'onions',
#   'whole milk',
#   'other vegetables',
#   'candy',
#   'whole milk',
#   'rolls/buns',
#   'candles',
#   'shopping bags',
#   'root vegetables',
#   'sugar',
#   'Instant food products',
#   'hard cheese',
#   'butter',
#   'soda',
#   'yogurt',
#   'newspapers',
#   'salty snack'],
#  ['frankfurter',
#   'citrus fruit',
#   'butter',
#   'rolls/buns',
#   'root vegetables',
#   'pip fruit',
#   'snack products',
#   'pastry',
#   'whole milk',
#   'canned beer',
#   'ham',
#   'chicken',
#   'frozen meals',
#   'other vegetables',
#   'newspapers',
#   'root vegetables',
#   'soda',
#   'butter milk',
#   'sausage',
#   'beef',
#   'coffee',
#   'beef',
#   'citrus fruit',
#   'rolls/buns',
#   'napkins',
#   'tropical fruit',
#   'whole milk',
#   'rolls/buns',
#   'bottled beer',
#   'whole milk',
#   'bottled water',
#   'whole milk',
#   'white wine',
#   'mayonnaise',
#   'whole milk',
#   'pip fruit',
#   'rolls/buns',
#   'UHT-milk',
#   'other vegetables',
#   'tropical fruit',
#   'hygiene articles',
#   'yogurt',
#   'bottled water',
#   'domestic eggs',
#   'white bread',
#   'UHT-milk',
#   'newspapers',
#   'pip fruit',
#   'soda',
#   'Instant food products',
#   'curd',
#   'newspapers',
#   'domestic eggs',
#   'rolls/buns',
#   'butter milk',
#   'napkins',
#   'mayonnaise',
#   'bottled water'],
#  ['frankfurter',
#   'oil',
#   'beef',
#   'long life bakery product',
#   'dessert',
#   'white bread',
#   'pastry',
#   'honey',
#   'curd',
#   'soda',
#   'oil',
#   'tropical fruit',
#   'waffles',
#   'rolls/buns',
#   'ice cream',
#   'soda',
#   'rolls/buns',
#   'citrus fruit',
#   'instant coffee',
#   'other vegetables',
#   'whole milk',
#   'margarine',
#   'rolls/buns',
#   'curd',
#   'root vegetables',
#   'whipped/sour cream',
#   'dessert',
#   'salty snack',
#   'brown bread',
#   'domestic eggs',
#   'butter',
#   'mustard',
#   'dishes',
#   'processed cheese',
#   'yogurt',
#   'whole milk',
#   'chewing gum',
#   'flour',
#   'shopping bags',
#   'margarine',
#   'meat spreads',
#   'domestic eggs',
#   'pot plants',
#   'soda',
#   'oil',
#   'butter'],
#  ['onions',
#   'rolls/buns',
#   'ham',
#   'pip fruit',
#   'tropical fruit',
#   'yogurt',
#   'soda',
#   'butter',
#   'liver loaf',
#   'whole milk',
#   'beverages',
#   'sausage',
#   'whole milk',
#   'ham',
#   'frankfurter',
#   'rolls/buns',
#   'berries',
#   'whole milk',
#   'root vegetables',
#   'meat',
#   'beverages',
#   'root vegetables',
#   'chicken',
#   'pastry',
#   'bottled beer',
#   'whole milk',
#   'cookware',
#   'specialty bar',
#   'tropical fruit',
#   'newspapers',
#   'whole milk',
#   'pastry',
#   'cream cheese ',
#   'yogurt',
#   'tropical fruit',
#   'rolls/buns',
#   'butter milk',
#   'whole milk',
#   'pastry',
#   'bottled water',
#   'rolls/buns',
#   'soda',
#   'newspapers',
#   'yogurt',
#   'coffee',
#   'herbs',
#   'other vegetables',
#   'UHT-milk',
#   'salty snack',
#   'herbs',
#   'newspapers',
#   'root vegetables',
#   'specialty bar',
#   'whipped/sour cream',
#   'spread cheese',
#   'hard cheese',
#   'margarine',
#   'yogurt',
#   'whole milk',
#   'candy',
#   'newspapers',
#   'pastry',
#   'oil',
#   'newspapers',
#   'baking powder',
#   'soda',
#   'red/blush wine',
#   'shopping bags',
#   'domestic eggs',
#   'chewing gum',
#   'whole milk',
#   'shopping bags',
#   'brown bread',
#   'abrasive cleaner'],
#  ['citrus fruit',
#   'rolls/buns',
#   'sausage',
#   'whipped/sour cream',
#   'soda',
#   'turkey',
#   'other vegetables',
#   'UHT-milk',
#   'pork',
#   'yogurt',
#   'root vegetables',
#   'processed cheese',
#   'tropical fruit',
#   'other vegetables',
#   'semi-finished bread',
#   'root vegetables',
#   'pork',
#   'turkey',
#   'pasta',
#   'flower (seeds)',
#   'ice cream',
#   'yogurt',
#   'dish cleaner',
#   'chewing gum',
#   'specialty bar',
#   'pastry',
#   'soda',
#   'dessert',
#   'fruit/vegetable juice',
#   'other vegetables',
#   'yogurt',
#   'rolls/buns',
#   'whole milk',
#   'processed cheese',
#   'tropical fruit',
#   'hygiene articles',
#   'curd',
#   'soda',
#   'soda',
#   'pastry',
#   'rolls/buns',
#   'newspapers',
#   'flower (seeds)',
#   'meat spreads',
#   'rolls/buns',
#   'curd',
#   'bottled water',
#   'frozen vegetables',
#   'shopping bags',
#   'napkins',
#   'dishes',
#   'sugar',
#   'domestic eggs',
#   'waffles',
#   'brown bread',
#   'long life bakery product',
#   'whole milk',
#   'pot plants',
#   'candles',
#   'waffles',
#   'yogurt'],
#  ['detergent',
#   'tropical fruit',
#   'sausage',
#   'citrus fruit',
#   'yogurt',
#   'frozen vegetables',
#   'sausage',
#   'tropical fruit',
#   'rolls/buns',
#   'canned beer',
#   'chicken',
#   'whole milk',
#   'fruit/vegetable juice',
#   'citrus fruit',
#   'chocolate',
#   'frankfurter',
#   'soda',
#   'chicken',
#   'sausage',
#   'yogurt',
#   'tropical fruit',
#   'whole milk',
#   'bottled beer',
#   'turkey',
#   'soda',
#   'meat',
#   'frankfurter',
#   'liver loaf',
#   'frozen meals',
#   'condensed milk',
#   'whole milk',
#   'brown bread',
#   'yogurt',
#   'cereals',
#   'rolls/buns',
#   'citrus fruit',
#   'tropical fruit',
#   'beverages',
#   'domestic eggs',
#   'sliced cheese',
#   'oil',
#   'brown bread',
#   'whole milk',
#   'yogurt',
#   'whipped/sour cream',
#   'canned vegetables',
#   'liquor (appetizer)',
#   'butter milk',
#   'herbs',
#   'root vegetables',
#   'citrus fruit',
#   'root vegetables',
#   'whole milk',
#   'grapes',
#   'yogurt',
#   'root vegetables',
#   'rice',
#   'condensed milk',
#   'specialty chocolate',
#   'whipped/sour cream',
#   'soda',
#   'rolls/buns',
#   'frozen meals',
#   'candles',
#   'bottled water',
#   'margarine'],
#  ['other vegetables',
#   'whole milk',
#   'citrus fruit',
#   'soda',
#   'curd',
#   'onions',
#   'ice cream',
#   'chocolate',
#   'whole milk',
#   'whole milk',
#   'butter milk',
#   'soda',
#   'meat',
#   'whole milk',
#   'frozen vegetables',
#   'ham',
#   'tropical fruit',
#   'whole milk',
#   'semi-finished bread',
#   'tropical fruit',
#   'misc. beverages',
#   'other vegetables',
#   'semi-finished bread',
#   'curd',
#   'cat food',
#   'specialty chocolate',
#   'whipped/sour cream',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'oil',
#   'liquor (appetizer)',
#   'other vegetables',
#   'specialty chocolate',
#   'pastry',
#   'napkins',
#   'bottled water',
#   'curd',
#   'berries',
#   'whipped/sour cream',
#   'domestic eggs',
#   'bottled water',
#   'domestic eggs',
#   'soda',
#   'coffee',
#   'UHT-milk',
#   'yogurt',
#   'coffee',
#   'cream cheese ',
#   'napkins',
#   'bottled beer',
#   'white wine'],
#  ['bottled water',
#   'sausage',
#   'oil',
#   'chicken',
#   'frozen meals',
#   'pip fruit',
#   'bottled water',
#   'pork',
#   'root vegetables',
#   'pork',
#   'citrus fruit',
#   'sausage',
#   'citrus fruit',
#   'pork',
#   'tropical fruit',
#   'beef',
#   'pork',
#   'whole milk',
#   'sausage',
#   'citrus fruit',
#   'beef',
#   'root vegetables',
#   'berries',
#   'berries',
#   'soda',
#   'newspapers',
#   'other vegetables',
#   'rolls/buns',
#   'newspapers',
#   'other vegetables',
#   'citrus fruit',
#   'brown bread',
#   'bottled water',
#   'frozen vegetables',
#   'other vegetables',
#   'other vegetables',
#   'pip fruit',
#   'dessert',
#   'margarine',
#   'roll products ',
#   'pastry',
#   'whole milk',
#   'brown bread',
#   'cat food',
#   'misc. beverages',
#   'rolls/buns',
#   'newspapers',
#   'specialty chocolate'],
#  ['tropical fruit',
#   'frankfurter',
#   'ham',
#   'sausage',
#   'pastry',
#   'curd',
#   'packaged fruit/vegetables',
#   'tropical fruit',
#   'other vegetables',
#   'pork',
# ...
#   'chicken',
#   'citrus fruit',
#   'whole milk',
#   'rolls/buns',
#   'butter',
#   'pork',
#   'ham',
#   'tropical fruit',
#   'pip fruit',
#   'sugar',
#   'female sanitary products',
#   'rolls/buns',
#   'root vegetables',
#   'UHT-milk',
#   'prosecco',
#   'frozen vegetables',
#   'chocolate',
#   'sauces',
#   'sugar',
#   'whole milk',
#   'grapes',
#   'butter milk',
#   'rolls/buns',
#   'semi-finished bread',
#   'sliced cheese',
#   'chocolate',
#   'bottled water',
#   'pastry',
#   'cat food',
#   'napkins',
#   'canned beer',
#   'hygiene articles',
#   'honey',
#   'ice cream',
#   'mustard',
#   'beverages',
#   'specialty bar',
#   'frozen fish',
#   'margarine',
#   'margarine',
#   'softener',
#   'shopping bags',
#   'newspapers',
#   'hygiene articles',
#   'whole milk',
#   'napkins',
#   'pickled vegetables',
#   'specialty bar',
#   'margarine',
#   'soda',
#   'dental care'],
#  ['packaged fruit/vegetables',
#   'specialty cheese',
#   'sausage',
#   'rolls/buns',
#   'other vegetables',
#   'yogurt',
#   'sausage',
#   'root vegetables',
#   'sausage',
#   'frankfurter',
#   'other vegetables',
#   'bottled water',
#   'coffee',
#   'domestic eggs',
#   'pork',
#   'sliced cheese',
#   'other vegetables',
#   'pork',
#   'pip fruit',
#   'salt',
#   'mayonnaise',
#   'sliced cheese',
#   'brown bread',
#   'berries',
#   'other vegetables',
#   'domestic eggs',
#   'newspapers',
#   'soda',
#   'meat spreads',
#   'fruit/vegetable juice'],
#  ['coffee',
#   'frozen dessert',
#   'whole milk',
#   'other vegetables',
#   'canned beer',
#   'other vegetables',
#   'sliced cheese',
#   'whole milk',
#   'curd',
#   'onions',
#   'root vegetables',
#   'soda',
#   'whole milk',
#   'newspapers',
#   'root vegetables',
#   'canned beer',
#   'packaged fruit/vegetables',
#   'soda',
#   'liquor',
#   'UHT-milk',
#   'fruit/vegetable juice',
#   'other vegetables',
#   'newspapers',
#   'napkins',
#   'bottled water',
#   'newspapers',
#   'margarine',
#   'coffee',
#   'vinegar',
#   'candles',
#   'soft cheese',
#   'margarine',
#   'cat food',
#   'salty snack',
#   'yogurt',
#   'other vegetables',
#   'dish cleaner',
#   'baking powder',
#   'white bread',
#   'rolls/buns',
#   'sparkling wine',
#   'hard cheese',
#   'frozen vegetables',
#   'oil',
#   'sugar',
#   'bottled water'],
#  ['tropical fruit',
#   'bottled water',
#   'meat',
#   'coffee',
#   'root vegetables',
#   'tropical fruit',
#   'detergent',
#   'hamburger meat',
#   'ham',
#   'soda',
#   'whole milk',
#   'sausage',
#   'sausage',
#   'canned beer',
#   'frankfurter',
#   'root vegetables',
#   'curd',
#   'candy',
#   'frankfurter',
#   'meat',
#   'chicken',
#   'whole milk',
#   'sausage',
#   'berries',
#   'frankfurter',
#   'white bread',
#   'pip fruit',
#   'other vegetables',
#   'processed cheese',
#   'bottled water',
#   'whole milk',
#   'root vegetables',
#   'root vegetables',
#   'pot plants',
#   'rolls/buns',
#   'rum',
#   'pastry',
#   'domestic eggs',
#   'napkins',
#   'whole milk',
#   'shopping bags',
#   'margarine',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'whipped/sour cream',
#   'domestic eggs',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'hygiene articles',
#   'soda',
#   'butter',
#   'jam',
#   'frozen vegetables',
#   'bottled beer',
#   'white bread',
#   'baking powder',
#   'whole milk',
#   'mustard',
#   'whipped/sour cream'],
#  ['bottled water',
#   'curd',
#   'tropical fruit',
#   'rolls/buns',
#   'root vegetables',
#   'sausage',
#   'soda',
#   'rolls/buns',
#   'citrus fruit',
#   'other vegetables',
#   'soda',
#   'newspapers',
#   'onions',
#   'whole milk',
#   'whole milk',
#   'soda',
#   'chicken',
#   'finished products',
#   'pip fruit',
#   'canned beer',
#   'beef',
#   'semi-finished bread',
#   'root vegetables',
#   'other vegetables',
#   'whipped/sour cream',
#   'other vegetables',
#   'yogurt',
#   'butter',
#   'sliced cheese',
#   'cake bar',
#   'butter',
#   'root vegetables',
#   'frozen vegetables',
#   'pip fruit',
#   'margarine',
#   'chocolate',
#   'curd cheese',
#   'newspapers',
#   'napkins',
#   'dish cleaner',
#   'domestic eggs',
#   'soda',
#   'specialty bar',
#   'specialty chocolate',
#   'chocolate',
#   'waffles'],
#  ['frankfurter',
#   'turkey',
#   'canned beer',
#   'other vegetables',
#   'dessert',
#   'brown bread',
#   'yogurt',
#   'domestic eggs',
#   'yogurt',
#   'citrus fruit',
#   'pork',
#   'frozen fish',
#   'rolls/buns',
#   'domestic eggs',
#   'other vegetables',
#   'onions',
#   'chicken',
#   'pip fruit',
#   'sausage',
#   'finished products',
#   'shopping bags',
#   'tropical fruit',
#   'pork',
#   'frankfurter',
#   'pip fruit',
#   'meat',
#   'canned beer',
#   'liquor (appetizer)',
#   'curd',
#   'bottled beer',
#   'other vegetables',
#   'cream cheese ',
#   'citrus fruit',
#   'brown bread',
#   'ice cream',
#   'coffee',
#   'whole milk',
#   'whole milk',
#   'herbs',
#   'flour',
#   'pork',
#   'chocolate marshmallow',
#   'other vegetables',
#   'shopping bags',
#   'rubbing alcohol',
#   'domestic eggs',
#   'oil',
#   'whole milk',
#   'whipped/sour cream',
#   'rolls/buns',
#   'bottled water',
#   'onions',
#   'rolls/buns'],
#  ['rolls/buns',
#   'grapes',
#   'frankfurter',
#   'hamburger meat',
#   'sausage',
#   'finished products',
#   'pet care',
#   'other vegetables',
#   'canned fish',
#   'other vegetables',
#   'root vegetables',
#   'decalcifier',
#   'coffee',
#   'long life bakery product',
#   'sausage',
#   'sausage',
#   'whole milk',
#   'ham',
#   'pip fruit',
#   'rolls/buns',
#   'yogurt',
#   'packaged fruit/vegetables',
#   'seasonal products',
#   'other vegetables',
#   'citrus fruit',
#   'berries',
#   'other vegetables',
#   'dish cleaner',
#   'salty snack',
#   'berries',
#   'butter milk',
#   'ice cream',
#   'yogurt',
#   'shopping bags',
#   'soda',
#   'grapes',
#   'whole milk',
#   'yogurt',
#   'softener',
#   'rolls/buns',
#   'bottled beer',
#   'bottled water',
#   'curd cheese',
#   'yogurt',
#   'red/blush wine',
#   'semi-finished bread',
#   'soups',
#   'whole milk',
#   'margarine',
#   'hygiene articles',
#   'pastry',
#   'fruit/vegetable juice',
#   'butter',
#   'domestic eggs',
#   'frozen vegetables',
#   'shopping bags',
#   'long life bakery product',
#   'snack products',
#   'brown bread',
#   'white bread',
#   'vinegar',
#   'Instant food products',
#   'long life bakery product',
#   'waffles'],
#  ['chocolate',
#   'root vegetables',
#   'ice cream',
#   'pork',
#   'chicken',
#   'herbs',
#   'frankfurter',
#   'pork',
#   'processed cheese',
#   'whole milk',
#   'misc. beverages',
#   'pip fruit',
#   'pet care',
#   'domestic eggs',
#   'liquor',
#   'other vegetables',
#   'frozen vegetables',
#   'whole milk',
#   'other vegetables',
#   'frankfurter',
#   'dessert',
#   'other vegetables',
#   'zwieback',
#   'pet care',
#   'sausage',
#   'meat',
#   'brown bread',
#   'pip fruit',
#   'sausage',
#   'waffles',
#   'rolls/buns',
#   'frozen dessert',
#   'citrus fruit',
#   'pastry',
#   'rolls/buns',
#   'soda',
#   'cream cheese ',
#   'domestic eggs',
#   'root vegetables',
#   'white bread',
#   'waffles',
#   'turkey',
#   'long life bakery product',
#   'coffee',
#   'cream cheese ',
#   'specialty chocolate',
#   'rolls/buns',
#   'pastry',
#   'tropical fruit',
#   'dishes',
#   'shopping bags',
#   'rolls/buns',
#   'white bread',
#   'whole milk',
#   'tropical fruit',
#   'other vegetables',
#   'pastry',
#   'other vegetables',
#   'whipped/sour cream',
#   'shopping bags',
#   'oil',
#   'bottled beer',
#   'salty snack',
#   'frozen vegetables',
#   'rolls/buns',
#   'newspapers',
#   'cling film/bags',
#   'specialty cheese',
#   'oil'],
#  ['other vegetables',
#   'whole milk',
#   'spread cheese',
#   'margarine',
#   'zwieback',
#   'root vegetables',
#   'specialty bar',
#   'butter milk',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'bottled beer',
#   'berries',
#   'pip fruit',
#   'frozen dessert',
#   'bottled water',
#   'liver loaf',
#   'brown bread',
#   'white wine',
#   'candy',
#   'pip fruit',
#   'other vegetables',
#   'bottled water',
#   'cream cheese ',
#   'dessert',
#   'candy',
#   'dessert',
#   'cat food',
#   'whole milk',
#   'rolls/buns',
#   'dog food',
#   'shopping bags',
#   'berries',
#   'whole milk',
#   'fruit/vegetable juice',
#   'pastry',
#   'brown bread',
#   'rolls/buns',
#   'margarine',
#   'rice',
#   'dental care',
#   'margarine',
#   'processed cheese',
#   'napkins',
#   'white bread',
#   'hygiene articles',
#   'newspapers'],
#  ['whole milk',
#   'sausage',
#   'bottled beer',
#   'sausage',
#   'yogurt',
#   'rolls/buns',
#   'root vegetables',
#   'canned beer',
#   'yogurt',
#   'rolls/buns',
#   'specialty chocolate',
#   'canned beer',
#   'citrus fruit',
#   'other vegetables',
#   'other vegetables',
#   'whole milk',
#   'whole milk',
#   'pip fruit',
#   'sausage',
#   'canned beer',
#   'condensed milk',
#   'chicken',
#   'chewing gum',
#   'whole milk',
#   'cocoa drinks',
#   'pot plants',
#   'newspapers',
#   'other vegetables',
#   'whole milk',
#   'whole milk',
#   'frozen vegetables',
#   'tropical fruit',
#   'rolls/buns',
#   'pip fruit',
#   'dessert',
#   'cream cheese ',
#   'root vegetables',
#   'whole milk',
#   'newspapers',
#   'cream cheese ',
#   'cling film/bags',
#   'bottled water',
#   'packaged fruit/vegetables',
#   'soda',
#   'pastry',
#   'yogurt',
#   'candy',
#   'bottled water',
#   'spread cheese',
#   'shopping bags',
#   'flour',
#   'meat spreads',
#   'soft cheese',
#   'shopping bags'],
#  ['ham',
#   'hamburger meat',
#   'yogurt',
#   'citrus fruit',
#   'other vegetables',
#   'hygiene articles',
#   'other vegetables',
#   'fruit/vegetable juice',
#   'rolls/buns',
#   'margarine',
#   'whole milk',
#   'pip fruit',
#   'tropical fruit',
#   'onions',
#   'tropical fruit',
#   'other vegetables',
#   'pip fruit',
#   'herbs',
#   'soda',
#   'cream cheese ',
#   'bottled beer',
#   'bottled water',
#   'pork',
#   'whole milk',
#   'domestic eggs',
#   'pastry',
#   'rolls/buns',
#   'yogurt',
#   'shopping bags',
#   'pastry',
#   'rolls/buns',
#   'soda',
#   'soda',
#   'mayonnaise',
#   'chocolate',
#   'soda',
#   'butter',
#   'brown bread',
#   'curd',
#   'yogurt',
#   'soda',
#   'soft cheese',
#   'napkins',
#   'UHT-milk',
#   'curd',
#   'coffee',
#   'shopping bags',
#   'dessert',
#   'dog food',
#   'bottled water',
#   'shopping bags',
#   'tropical fruit',
#   'dishes',
#   'rolls/buns',
#   'chocolate',
#   'canned vegetables',
#   'brown bread',
#   'other vegetables',
#   'bottled beer',
#   'whole milk',
#   'cake bar',
#   'brown bread',
#   'soda',
#   'UHT-milk',
#   'salty snack',
#   'canned beer',
#   'pastry',
#   'flour',
#   'whole milk',
#   'canned beer',
#   'ice cream',
#   'misc. beverages',
#   'newspapers',
#   'yogurt',
#   'shopping bags'],
#  ['coffee',
#   'hamburger meat',
#   'beef',
#   'condensed milk',
#   'canned beer',
#   'citrus fruit',
#   'salty snack',
#   'pork',
#   'long life bakery product',
#   'dessert',
#   'canned beer',
#   'ham',
#   'sausage',
#   'yogurt',
#   'canned beer',
#   'bottled water',
#   'sausage',
#   'other vegetables',
#   'beverages',
#   'rolls/buns',
#   'shopping bags',
#   'root vegetables',
#   'ice cream',
#   'processed cheese',
#   'yogurt',
#   'fruit/vegetable juice',
#   'rolls/buns',
#   'yogurt',
#   'butter milk',
#   'frozen meals',
#   'mustard',
#   'tropical fruit',
#   'soda',
#   'rolls/buns',
#   'berries',
#   'pastry',
#   'specialty bar',
#   'specialty bar',
#   'red/blush wine',
#   'oil',
#   'fruit/vegetable juice',
#   'red/blush wine',
#   'canned beer',
#   'popcorn',
#   'whipped/sour cream',
#   'popcorn',
#   'rolls/buns'],
#  ['canned fish',
#   'frankfurter',
#   'canned beer',
#   'candy',
#   'yogurt',
#   'rolls/buns',
#   'beverages',
#   'pip fruit',
#   'other vegetables',
#   'chicken',
#   'hard cheese',
#   'salt',
#   'canned beer',
#   'whipped/sour cream',
#   'whole milk',
#   'other vegetables',
#   'other vegetables',
#   'tropical fruit',
#   'sugar',
#   'pork',
#   'onions',
#   'turkey',
#   'beef',
#   'yogurt',
#   'butter',
#   'whole milk',
#   'rolls/buns',
#   'cream cheese ',
#   'semi-finished bread',
#   'shopping bags',
#   'specialty fat',
#   'butter',
#   'pip fruit',
#   'house keeping products',
#   'processed cheese',
#   'root vegetables',
#   'white bread',
#   'hard cheese',
#   'ice cream',
#   'rolls/buns',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'seasonal products',
#   'napkins',
#   'canned fruit',
#   'root vegetables',
#   'frozen vegetables',
#   'butter',
#   'canned fish',
#   'soda',
#   'brown bread',
#   'soda',
#   'flour',
#   'cream cheese ',
#   'pot plants',
#   'cat food',
#   'brown bread'],
#  ['vinegar',
#   'chicken',
#   'root vegetables',
#   'chicken',
#   'sausage',
#   'whipped/sour cream',
#   'sausage',
#   'other vegetables',
#   'canned beer',
#   'dishes',
#   'pip fruit',
#   'light bulbs',
#   'whole milk',
#   'bottled beer',
#   'pork',
#   'whole milk',
#   'soda',
#   'meat',
#   'other vegetables',
#   'soda',
#   'root vegetables',
#   'sausage',
#   'flower soil/fertilizer',
#   'ham',
#   'sausage',
#   'sausage',
#   'rolls/buns',
#   'sweet spreads',
#   'butter milk',
#   'rolls/buns',
#   'rolls/buns',
#   'yogurt',
#   'other vegetables',
#   'whole milk',
#   'bottled beer',
#   'cream cheese ',
#   'instant coffee',
#   'bottled water',
#   'butter',
#   'dessert',
#   'candles',
#   'whole milk',
#   'other vegetables',
#   'tropical fruit',
#   'soda',
#   'other vegetables',
#   'whole milk',
#   'other vegetables',
#   'other vegetables',
#   'whipped/sour cream',
#   'shopping bags',
#   'misc. beverages',
#   'rolls/buns',
#   'whole milk',
#   'other vegetables',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'shopping bags',
#   'cream cheese ',
#   'processed cheese',
#   'candy',
#   'rolls/buns',
#   'salty snack'],
#  ['pork',
#   'other vegetables',
#   'beef',
#   'whole milk',
#   'hygiene articles',
#   'whole milk',
#   'hamburger meat',
#   'root vegetables',
#   'other vegetables',
#   'other vegetables',
#   'meat',
#   'margarine',
#   'UHT-milk',
#   'beverages',
#   'other vegetables',
#   'brown bread',
#   'soda',
#   'packaged fruit/vegetables',
#   'sausage',
#   'rolls/buns',
#   'ham',
#   'chocolate',
#   'soft cheese',
#   'shopping bags',
#   'whole milk',
#   'brown bread',
#   'shopping bags',
#   'margarine',
#   'fruit/vegetable juice',
#   'dog food',
#   'other vegetables',
#   'detergent',
#   'herbs',
#   'cooking chocolate',
#   'white wine',
#   'yogurt',
#   'whole milk',
#   'waffles',
#   'yogurt',
#   'shopping bags',
#   'soda',
#   'yogurt',
#   'rolls/buns',
#   'canned beer',
#   'specialty chocolate',
#   'soap',
#   'frozen potato products'],
#  ['brown bread',
#   'frankfurter',
#   'chicken',
#   'citrus fruit',
#   'berries',
#   'whole milk',
#   'rolls/buns',
#   'whole milk',
#   'ham',
#   'citrus fruit',
#   'canned beer',
#   'sausage',
#   'sausage',
#   'whisky',
#   'chicken',
#   'root vegetables',
#   'tropical fruit',
#   'rolls/buns',
#   'chicken',
#   'pip fruit',
#   'specialty chocolate',
#   'tropical fruit',
#   'rolls/buns',
#   'salty snack',
#   'butter milk',
#   'pastry',
#   'whipped/sour cream',
#   'butter milk',
#   'root vegetables',
#   'other vegetables',
#   'bottled beer',
#   'instant coffee',
#   'dishes',
#   'margarine',
#   'yogurt',
#   'misc. beverages',
#   'ice cream',
#   'rolls/buns',
#   'whole milk',
#   'yogurt',
#   'yogurt',
#   'napkins',
#   'roll products ',
#   'frozen vegetables',
#   'detergent',
#   'pastry',
#   'newspapers'],
#  ['yogurt',
#   'frankfurter',
#   'other vegetables',
#   'salty snack',
#   'sweet spreads',
#   'pastry',
#   'specialty bar',
#   'root vegetables',
#   'white wine',
#   'root vegetables',
#   'bottled water',
#   'cream cheese ',
#   'chicken',
#   'pip fruit',
#   'beef',
#   'butter',
#   'canned beer',
#   'misc. beverages',
#   'whole milk',
#   'grapes',
#   'other vegetables',
#   'soda',
#   'soda',
#   'condensed milk',
#   'herbs',
#   'other vegetables',
#   'bottled beer',
#   'rum',
#   'butter',
#   'instant coffee',
#   'herbs',
#   'frozen vegetables',
#   'frozen vegetables',
#   'margarine',
#   'misc. beverages',
#   'domestic eggs',
#   'canned beer',
#   'red/blush wine',
#   'other vegetables',
#   'whole milk',
#   'frozen fish',
#   'root vegetables',
#   'domestic eggs',
#   'bottled beer',
#   'bottled water',
#   'onions',
#   'shopping bags',
#   'salt',
#   'pastry',
#   'bottled beer',
#   'sliced cheese',
#   'rolls/buns',
#   'margarine',
#   'ice cream',
#   'napkins',
#   'oil',
#   'long life bakery product'],
#  ['chicken',
#   'canned beer',
#   'frozen vegetables',
#   'beef',
#   'canned beer',
#   'chicken',
#   'tropical fruit',
#   'bottled water',
#   'frozen meals',
#   'tropical fruit',
#   'salty snack',
#   'finished products',
#   'bottled beer',
#   'rolls/buns',
#   'brown bread',
#   'pip fruit',
#   'beef',
#   'other vegetables',
#   'other vegetables',
#   'chocolate',
#   'specialty chocolate',
#   'curd',
#   'other vegetables',
#   'whole milk',
#   'hard cheese',
#   'bottled beer',
#   'oil',
#   'salty snack',
#   'other vegetables',
#   'pickled vegetables',
#   'yogurt',
#   'whole milk',
#   'domestic eggs',
#   'yogurt',
#   'chocolate',
#   'pastry',
#   'whipped/sour cream',
#   'other vegetables',
#   'frozen vegetables',
#   'packaged fruit/vegetables',
#   'brown bread',
#   'shopping bags',
#   'napkins',
#   'salty snack',
#   'newspapers',
#   'candy']]

# %%
from apyori import apriori
rules = apriori(transactions=transactions,min_support=0.005,min_confidence=0.7,min_lift=3,
                min_length=3,max_length=3)

# %%
#visualizing results

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'salad dressing', 'oil'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'female sanitary products', 'Instant food products', 'semi-finished bread'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'female sanitary products', 'Instant food products'}), items_add=frozenset({'semi-finished bread'}), confidence=0.8, lift=4.585826771653544)]),
#  RelationRecord(items=frozenset({'salt', 'mustard', 'Instant food products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mustard', 'Instant food products'}), items_add=frozenset({'salt'}), confidence=0.8, lift=7.372151898734177)]),
#  RelationRecord(items=frozenset({'Instant food products', 'pickled vegetables', 'spread cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Instant food products', 'spread cheese'}), items_add=frozenset({'pickled vegetables'}), confidence=0.8, lift=4.813223140495868)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'Instant food products', 'spread cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Instant food products', 'spread cheese'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'chewing gum', 'abrasive cleaner', 'UHT-milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'abrasive cleaner', 'UHT-milk'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'ready soups', 'candy', 'UHT-milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ready soups', 'UHT-milk'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'candy', 'skin care', 'UHT-milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'skin care', 'UHT-milk'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'chewing gum', 'snack products', 'UHT-milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'snack products', 'UHT-milk'}), items_add=frozenset({'chewing gum'}), confidence=0.7142857142857142, lift=3.190184049079754)]),
#  RelationRecord(items=frozenset({'pasta', 'flower soil/fertilizer', 'UHT-milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flower soil/fertilizer', 'UHT-milk'}), items_add=frozenset({'pasta'}), confidence=0.8, lift=5.153982300884956)]),
#  RelationRecord(items=frozenset({'frozen fruits', 'sugar', 'UHT-milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen fruits', 'UHT-milk'}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'organic products', 'hard cheese', 'UHT-milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic products', 'UHT-milk'}), items_add=frozenset({'hard cheese'}), confidence=0.8, lift=3.1481081081081084)]),
#  RelationRecord(items=frozenset({'hygiene articles', 'prosecco', 'UHT-milk'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'prosecco', 'UHT-milk'}), items_add=frozenset({'hygiene articles'}), confidence=0.8571428571428571, lift=3.4475138121546958)]),
#  RelationRecord(items=frozenset({'meat spreads', 'UHT-milk', 'long life bakery product'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat spreads', 'UHT-milk'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'syrup', 'processed cheese', 'UHT-milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'syrup', 'UHT-milk'}), items_add=frozenset({'processed cheese'}), confidence=0.7142857142857142, lift=3.741007194244604)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'UHT-milk', 'pudding powder'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk', 'pudding powder'}), items_add=frozenset({'sliced cheese'}), confidence=0.8333333333333333, lift=3.261648745519713)]),
#  RelationRecord(items=frozenset({'abrasive cleaner', 'oil', 'baking powder'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'abrasive cleaner', 'baking powder'}), items_add=frozenset({'oil'}), confidence=1.0, lift=3.7333333333333334), OrderedStatistic(items_base=frozenset({'abrasive cleaner', 'oil'}), items_add=frozenset({'baking powder'}), confidence=0.7142857142857142, lift=4.727272727272727)]),
#  RelationRecord(items=frozenset({'chewing gum', 'abrasive cleaner', 'beverages'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'abrasive cleaner', 'beverages'}), items_add=frozenset({'chewing gum'}), confidence=0.7142857142857142, lift=3.190184049079754)]),
#  RelationRecord(items=frozenset({'ham', 'candy', 'abrasive cleaner'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham', 'abrasive cleaner'}), items_add=frozenset({'candy'}), confidence=0.8333333333333333, lift=3.1433506044905006)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'abrasive cleaner', 'flour'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'abrasive cleaner', 'flour'}), items_add=frozenset({'specialty chocolate'}), confidence=0.8333333333333333, lift=3.0485762144053603)]),
#  RelationRecord(items=frozenset({'red/blush wine', 'cat food', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'red/blush wine', 'artif. sweetener'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'fruit/vegetable juice', 'chewing gum', 'artif. sweetener'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fruit/vegetable juice', 'artif. sweetener'}), items_add=frozenset({'chewing gum'}), confidence=0.7000000000000001, lift=3.1263803680981597)]),
#  RelationRecord(items=frozenset({'chewing gum', 'pickled vegetables', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pickled vegetables', 'artif. sweetener'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'specialty bar', 'coffee', 'artif. sweetener'}), support=0.01098901098901099, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee', 'artif. sweetener'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'herbs', 'dishes', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'dishes', 'artif. sweetener'}), items_add=frozenset({'herbs'}), confidence=0.8, lift=4.189928057553957)]),
#  RelationRecord(items=frozenset({'specialty bar', 'ice cream', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ice cream', 'artif. sweetener'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'white wine', 'ice cream', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ice cream', 'artif. sweetener'}), items_add=frozenset({'white wine'}), confidence=0.8, lift=3.7095541401273886)]),
#  RelationRecord(items=frozenset({'sparkling wine', 'meat', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sparkling wine', 'artif. sweetener'}), items_add=frozenset({'meat'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'spread cheese', 'pickled vegetables', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pickled vegetables', 'artif. sweetener'}), items_add=frozenset({'spread cheese'}), confidence=0.8, lift=6.130526315789473)]),
#  RelationRecord(items=frozenset({'white wine', 'sparkling wine', 'artif. sweetener'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sparkling wine', 'artif. sweetener'}), items_add=frozenset({'white wine'}), confidence=1.0, lift=4.6369426751592355)]),
#  RelationRecord(items=frozenset({'margarine', 'bags', 'butter'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bags'}), items_add=frozenset({'margarine', 'butter'}), confidence=1.0, lift=4.136363636363637)]),
#  RelationRecord(items=frozenset({'pip fruit', 'margarine', 'bags'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bags'}), items_add=frozenset({'pip fruit', 'margarine'}), confidence=1.0, lift=3.294117647058824)]),
#  RelationRecord(items=frozenset({'brown bread', 'baking powder', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brown bread', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8, lift=5.294545454545455)]),
#  RelationRecord(items=frozenset({'butter milk', 'curd cheese', 'baking powder'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd cheese', 'baking powder'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'canned beer', 'baking powder', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned beer', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8, lift=5.294545454545455)]),
#  RelationRecord(items=frozenset({'chocolate', 'baking powder', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=1.0, lift=6.618181818181818)]),
#  RelationRecord(items=frozenset({'light bulbs', 'cling film/bags', 'baking powder'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'baking powder'}), items_add=frozenset({'cling film/bags'}), confidence=0.8, lift=8.32)]),
#  RelationRecord(items=frozenset({'curd', 'baking powder', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=1.0, lift=6.618181818181818)]),
#  RelationRecord(items=frozenset({'domestic eggs', 'baking powder', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'domestic eggs', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8, lift=5.294545454545455)]),
#  RelationRecord(items=frozenset({'hard cheese', 'baking powder', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hard cheese', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8, lift=5.294545454545455)]),
#  RelationRecord(items=frozenset({'herbs', 'baking powder', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herbs', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=1.0, lift=6.618181818181818)]),
#  RelationRecord(items=frozenset({'newspapers', 'baking powder', 'decalcifier'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'newspapers', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.75, lift=4.963636363636364)]),
#  RelationRecord(items=frozenset({'pastry', 'baking powder', 'decalcifier'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pastry', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8333333333333333, lift=5.515151515151515)]),
#  RelationRecord(items=frozenset({'root vegetables', 'baking powder', 'decalcifier'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.7142857142857142, lift=4.727272727272727)]),
#  RelationRecord(items=frozenset({'tropical fruit', 'baking powder', 'decalcifier'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.8333333333333333, lift=5.515151515151515)]),
#  RelationRecord(items=frozenset({'yogurt', 'baking powder', 'decalcifier'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'decalcifier'}), items_add=frozenset({'baking powder'}), confidence=0.7142857142857142, lift=4.727272727272727)]),
#  RelationRecord(items=frozenset({'fish', 'specialty bar', 'baking powder'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fish', 'baking powder'}), items_add=frozenset({'specialty bar'}), confidence=1.0, lift=3.956521739130435)]),
#  RelationRecord(items=frozenset({'ice cream', 'turkey', 'baking powder'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'turkey', 'baking powder'}), items_add=frozenset({'ice cream'}), confidence=0.8571428571428571, lift=3.0144927536231885)]),
#  RelationRecord(items=frozenset({'semi-finished bread', 'baking powder', 'pet care'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'baking powder', 'pet care'}), items_add=frozenset({'semi-finished bread'}), confidence=0.7000000000000001, lift=4.012598425196851)]),
#  RelationRecord(items=frozenset({'potato products', 'specialty bar', 'baking powder'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'potato products', 'baking powder'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'candy', 'bathroom cleaner'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese', 'bathroom cleaner'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'grapes', 'condensed milk', 'bathroom cleaner'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'condensed milk', 'bathroom cleaner'}), items_add=frozenset({'grapes'}), confidence=1.0, lift=4.089887640449438), OrderedStatistic(items_base=frozenset({'grapes', 'bathroom cleaner'}), items_add=frozenset({'condensed milk'}), confidence=0.8, lift=6.471111111111111)]),
#  RelationRecord(items=frozenset({'waffles', 'condensed milk', 'bathroom cleaner'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'condensed milk', 'bathroom cleaner'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'berries', 'salad dressing', 'oil'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'berries', 'salad dressing'}), items_add=frozenset({'oil'}), confidence=1.0, lift=3.7333333333333334)]),
#  RelationRecord(items=frozenset({'beverages', 'snack products', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'snack products'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'ham', 'beverages', 'snack products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'snack products'}), items_add=frozenset({'ham'}), confidence=1.0, lift=3.4018691588785046)]),
#  RelationRecord(items=frozenset({'whisky', 'beverages', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whisky', 'long life bakery product'}), items_add=frozenset({'beverages'}), confidence=1.0, lift=3.4178403755868545)]),
#  RelationRecord(items=frozenset({'soft cheese', 'nut snack', 'beverages'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nut snack', 'soft cheese'}), items_add=frozenset({'beverages'}), confidence=1.0, lift=3.4178403755868545)]),
#  RelationRecord(items=frozenset({'syrup', 'beverages', 'processed cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'syrup', 'beverages'}), items_add=frozenset({'processed cheese'}), confidence=0.8, lift=4.189928057553957)]),
#  RelationRecord(items=frozenset({'specialty bar', 'beverages', 'rum'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'rum'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'waffles', 'beverages', 'rum'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'rum'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'salty snack', 'beverages', 'tea'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages', 'tea'}), items_add=frozenset({'salty snack'}), confidence=1.0, lift=3.1790393013100435)]),
#  RelationRecord(items=frozenset({'make up remover', 'bottled beer', 'chocolate'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'make up remover'}), items_add=frozenset({'bottled beer', 'chocolate'}), confidence=0.8, lift=3.64)]),
#  RelationRecord(items=frozenset({'make up remover', 'margarine', 'bottled beer'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'make up remover'}), items_add=frozenset({'bottled beer', 'margarine'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'brandy', 'cake bar', 'white wine'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brandy', 'white wine'}), items_add=frozenset({'cake bar'}), confidence=0.7142857142857142, lift=5.909090909090908)]),
#  RelationRecord(items=frozenset({'brandy', 'pot plants', 'ham'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brandy', 'pot plants'}), items_add=frozenset({'ham'}), confidence=1.0, lift=3.4018691588785046)]),
#  RelationRecord(items=frozenset({'brandy', 'popcorn', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brandy', 'popcorn'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'brandy', 'specialty chocolate', 'processed cheese'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brandy', 'processed cheese'}), items_add=frozenset({'specialty chocolate'}), confidence=0.8333333333333333, lift=3.0485762144053603)]),
#  RelationRecord(items=frozenset({'brown bread', 'chewing gum', 'cookware'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brown bread', 'cookware'}), items_add=frozenset({'chewing gum'}), confidence=0.75, lift=3.349693251533742)]),
#  RelationRecord(items=frozenset({'flower soil/fertilizer', 'butter', 'misc. beverages'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flower soil/fertilizer', 'butter'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'salad dressing', 'butter'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing', 'butter'}), items_add=frozenset({'misc. beverages'}), confidence=1.0, lift=3.8930481283422465)]),
#  RelationRecord(items=frozenset({'canned vegetables', 'butter milk', 'rice'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'rice'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'canned vegetables', 'butter milk', 'softener'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'softener'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'dental care', 'cat food', 'butter milk'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'dental care', 'cat food'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'male cosmetics', 'cat food', 'butter milk'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'male cosmetics', 'butter milk'}), items_add=frozenset({'cat food'}), confidence=0.7777777777777779, lift=3.6530465949820794)]),
#  RelationRecord(items=frozenset({'frozen dessert', 'cereals', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen dessert', 'cereals'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'organic products', 'chicken', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic products', 'chicken'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'chocolate marshmallow', 'flower (seeds)', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate marshmallow', 'flower (seeds)'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'hard cheese', 'butter milk', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter milk', 'decalcifier'}), items_add=frozenset({'hard cheese'}), confidence=0.8, lift=3.1481081081081084)]),
#  RelationRecord(items=frozenset({'sausage', 'butter milk', 'decalcifier'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'decalcifier'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'toilet cleaner', 'domestic eggs', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'toilet cleaner'}), items_add=frozenset({'domestic eggs', 'butter milk'}), confidence=0.8, lift=4.6967741935483875), OrderedStatistic(items_base=frozenset({'toilet cleaner', 'domestic eggs'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'vinegar', 'finished products', 'butter milk'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'vinegar', 'finished products'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'sparkling wine', 'flower (seeds)', 'butter milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sparkling wine', 'flower (seeds)'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'frozen dessert', 'butter milk', 'rice'}), support=0.01098901098901099, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen dessert', 'rice'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'grapes', 'snack products', 'butter milk'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'grapes', 'snack products'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'hair spray', 'hygiene articles', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hair spray', 'butter milk'}), items_add=frozenset({'hygiene articles'}), confidence=0.8, lift=3.2176795580110498), OrderedStatistic(items_base=frozenset({'hair spray', 'hygiene articles'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'hamburger meat', 'potato products', 'butter milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'potato products', 'hamburger meat'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'honey', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese', 'honey'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'kitchen towels', 'processed cheese', 'butter milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'kitchen towels', 'butter milk'}), items_add=frozenset({'processed cheese'}), confidence=0.7142857142857142, lift=3.741007194244604)]),
#  RelationRecord(items=frozenset({'liquor', 'butter milk', 'organic sausage'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liquor', 'organic sausage'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'toilet cleaner', 'napkins', 'butter milk'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'toilet cleaner'}), items_add=frozenset({'napkins', 'butter milk'}), confidence=0.8, lift=6.195744680851064), OrderedStatistic(items_base=frozenset({'toilet cleaner', 'napkins'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'syrup', 'processed cheese', 'butter milk'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'syrup', 'butter milk'}), items_add=frozenset({'processed cheese'}), confidence=0.7777777777777779, lift=4.073541167066348)]),
#  RelationRecord(items=frozenset({'toilet cleaner', 'butter milk', 'soda'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'toilet cleaner', 'soda'}), items_add=frozenset({'butter milk'}), confidence=1.0, lift=3.192982456140351)]),
#  RelationRecord(items=frozenset({'candy', 'cake bar', 'soups'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soups', 'cake bar'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'hygiene articles', 'canned vegetables', 'cake bar'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'cake bar'}), items_add=frozenset({'hygiene articles'}), confidence=0.8571428571428571, lift=3.4475138121546958)]),
#  RelationRecord(items=frozenset({'cereals', 'cake bar', 'pickled vegetables'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'cake bar'}), items_add=frozenset({'pickled vegetables'}), confidence=0.8, lift=4.813223140495868)]),
#  RelationRecord(items=frozenset({'detergent', 'soups', 'cake bar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soups', 'cake bar'}), items_add=frozenset({'detergent'}), confidence=0.8, lift=4.894117647058824)]),
#  RelationRecord(items=frozenset({'frozen potato products', 'cake bar', 'finished products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake bar', 'finished products'}), items_add=frozenset({'frozen potato products'}), confidence=0.8, lift=8.692537313432835)]),
#  RelationRecord(items=frozenset({'softener', 'cake bar', 'flour'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake bar', 'softener'}), items_add=frozenset({'flour'}), confidence=0.8, lift=4.314074074074074)]),
#  RelationRecord(items=frozenset({'jam', 'sugar', 'cake bar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'jam', 'cake bar'}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'cling film/bags', 'candles'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cling film/bags', 'candles'}), items_add=frozenset({'specialty chocolate'}), confidence=1.0, lift=3.6582914572864325)]),
#  RelationRecord(items=frozenset({'condensed milk', 'oil', 'candles'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'condensed milk', 'candles'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'frozen potato products', 'candles'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen potato products', 'candles'}), items_add=frozenset({'specialty chocolate'}), confidence=0.8333333333333333, lift=3.0485762144053603)]),
#  RelationRecord(items=frozenset({'zwieback', 'meat', 'candles'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback', 'candles'}), items_add=frozenset({'meat'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'pet care', 'candles'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pet care', 'candles'}), items_add=frozenset({'specialty chocolate'}), confidence=1.0, lift=3.6582914572864325)]),
#  RelationRecord(items=frozenset({'specialty cheese', 'sparkling wine', 'candles'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sparkling wine', 'candles'}), items_add=frozenset({'specialty cheese'}), confidence=0.8, lift=8.32)]),
#  RelationRecord(items=frozenset({'potato products', 'candy', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'potato products', 'cat food'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'candy', 'condensed milk', 'rum'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'condensed milk', 'rum'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'rum', 'candy', 'flour'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rum', 'flour'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'house keeping products', 'candy', 'ketchup'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'house keeping products', 'ketchup'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'candy', 'hygiene articles', 'prosecco'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candy', 'prosecco'}), items_add=frozenset({'hygiene articles'}), confidence=0.8, lift=3.2176795580110498)]),
#  RelationRecord(items=frozenset({'light bulbs', 'mustard', 'candy'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'mustard'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'candy', 'liquor', 'skin care'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liquor', 'skin care'}), items_add=frozenset({'candy'}), confidence=1.0, lift=3.772020725388601)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'candy', 'nut snack'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candy', 'nut snack'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797), OrderedStatistic(items_base=frozenset({'misc. beverages', 'nut snack'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'roll products ', 'candy', 'photo/film'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'roll products ', 'photo/film'}), items_add=frozenset({'candy'}), confidence=0.8, lift=3.017616580310881)]),
#  RelationRecord(items=frozenset({'make up remover', 'canned beer', 'chocolate'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'make up remover'}), items_add=frozenset({'canned beer', 'chocolate'}), confidence=0.8, lift=3.2355555555555555)]),
#  RelationRecord(items=frozenset({'cream cheese ', 'canned beer', 'rubbing alcohol'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rubbing alcohol'}), items_add=frozenset({'cream cheese ', 'canned beer'}), confidence=0.8, lift=3.4058479532163743)]),
#  RelationRecord(items=frozenset({'canned fish', 'male cosmetics', 'cat food'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'male cosmetics'}), items_add=frozenset({'cat food'}), confidence=0.8333333333333333, lift=3.9139784946236555)]),
#  RelationRecord(items=frozenset({'canned fish', 'dishes', 'organic sausage'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'organic sausage'}), items_add=frozenset({'dishes'}), confidence=0.8333333333333333, lift=4.892473118279569), OrderedStatistic(items_base=frozenset({'dishes', 'organic sausage'}), items_add=frozenset({'canned fish'}), confidence=1.0, lift=7.207920792079207)]),
#  RelationRecord(items=frozenset({'canned fish', 'grapes', 'soups'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'soups'}), items_add=frozenset({'grapes'}), confidence=1.0, lift=4.089887640449438)]),
#  RelationRecord(items=frozenset({'canned fish', 'organic sausage', 'hamburger meat'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic sausage', 'hamburger meat'}), items_add=frozenset({'canned fish'}), confidence=0.8, lift=5.766336633663366)]),
#  RelationRecord(items=frozenset({'nuts/prunes', 'canned fish', 'hard cheese'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nuts/prunes', 'canned fish'}), items_add=frozenset({'hard cheese'}), confidence=0.8333333333333333, lift=3.279279279279279)]),
#  RelationRecord(items=frozenset({'canned fish', 'specialty cheese', 'liquor (appetizer)'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty cheese', 'liquor (appetizer)'}), items_add=frozenset({'canned fish'}), confidence=0.8, lift=5.766336633663366)]),
#  RelationRecord(items=frozenset({'ready soups', 'misc. beverages', 'canned fish'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ready soups', 'canned fish'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'pasta', 'canned fish', 'tea'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'tea'}), items_add=frozenset({'pasta'}), confidence=0.8, lift=5.153982300884956)]),
#  RelationRecord(items=frozenset({'napkins', 'canned fruit', 'flour'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'napkins', 'canned fruit'}), items_add=frozenset({'flour'}), confidence=0.7142857142857142, lift=3.851851851851851)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'ham', 'canned fruit'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham', 'canned fruit'}), items_add=frozenset({'specialty chocolate'}), confidence=0.8333333333333333, lift=3.0485762144053603)]),
#  RelationRecord(items=frozenset({'hard cheese', 'processed cheese', 'canned fruit'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese', 'canned fruit'}), items_add=frozenset({'hard cheese'}), confidence=1.0, lift=3.9351351351351354)]),
#  RelationRecord(items=frozenset({'packaged fruit/vegetables', 'specialty bar', 'canned fruit'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'packaged fruit/vegetables', 'canned fruit'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'salty snack', 'fish', 'canned vegetables'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fish', 'canned vegetables'}), items_add=frozenset({'salty snack'}), confidence=1.0, lift=3.1790393013100435)]),
#  RelationRecord(items=frozenset({'grapes', 'canned vegetables', 'skin care'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'skin care'}), items_add=frozenset({'grapes'}), confidence=1.0, lift=4.089887640449438)]),
#  RelationRecord(items=frozenset({'house keeping products', 'red/blush wine', 'canned vegetables'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'house keeping products', 'canned vegetables'}), items_add=frozenset({'red/blush wine'}), confidence=0.8333333333333333, lift=4.302600472813238)]),
#  RelationRecord(items=frozenset({'instant coffee', 'hygiene articles', 'canned vegetables'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'instant coffee', 'canned vegetables'}), items_add=frozenset({'hygiene articles'}), confidence=0.75, lift=3.016574585635359)]),
#  RelationRecord(items=frozenset({'popcorn', 'hygiene articles', 'canned vegetables'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'popcorn', 'canned vegetables'}), items_add=frozenset({'hygiene articles'}), confidence=0.75, lift=3.016574585635359)]),
#  RelationRecord(items=frozenset({'waffles', 'canned vegetables', 'ketchup'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned vegetables', 'ketchup'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'sauces', 'specialty bar', 'canned vegetables'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sauces', 'canned vegetables'}), items_add=frozenset({'specialty bar'}), confidence=1.0, lift=3.956521739130435)]),
#  RelationRecord(items=frozenset({'cereals', 'cat food', 'liquor'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'liquor'}), items_add=frozenset({'cat food'}), confidence=0.8333333333333333, lift=3.9139784946236555)]),
#  RelationRecord(items=frozenset({'fruit/vegetable juice', 'hair spray', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fruit/vegetable juice', 'hair spray'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'nuts/prunes', 'hard cheese', 'cat food'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nuts/prunes', 'cat food'}), items_add=frozenset({'hard cheese'}), confidence=0.8333333333333333, lift=3.279279279279279)]),
#  RelationRecord(items=frozenset({'house keeping products', 'cat food', 'seasonal products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'house keeping products', 'seasonal products'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'hygiene articles', 'cat food', 'ketchup'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cat food', 'ketchup'}), items_add=frozenset({'hygiene articles'}), confidence=0.8, lift=3.2176795580110498)]),
#  RelationRecord(items=frozenset({'hygiene articles', 'male cosmetics', 'cat food'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hygiene articles', 'male cosmetics'}), items_add=frozenset({'cat food'}), confidence=0.7142857142857142, lift=3.354838709677419)]),
#  RelationRecord(items=frozenset({'light bulbs', 'cat food', 'seasonal products'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'seasonal products'}), items_add=frozenset({'cat food'}), confidence=1.0, lift=4.6967741935483875)]),
#  RelationRecord(items=frozenset({'zwieback', 'liquor (appetizer)', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback', 'liquor (appetizer)'}), items_add=frozenset({'cat food'}), confidence=1.0, lift=4.6967741935483875)]),
#  RelationRecord(items=frozenset({'liver loaf', 'cat food', 'vinegar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liver loaf', 'vinegar'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'napkins', 'male cosmetics', 'cat food'}), support=0.01098901098901099, ordered_statistics=[OrderedStatistic(items_base=frozenset({'napkins', 'male cosmetics'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'spices', 'meat', 'cat food'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spices', 'meat'}), items_add=frozenset({'cat food'}), confidence=0.7000000000000001, lift=3.2877419354838713)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'nut snack', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nut snack', 'cat food'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'tidbits', 'pot plants', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tidbits', 'pot plants'}), items_add=frozenset({'cat food'}), confidence=0.8, lift=3.75741935483871)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'tidbits', 'cat food'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese', 'tidbits'}), items_add=frozenset({'cat food'}), confidence=0.7142857142857142, lift=3.354838709677419)]),
#  RelationRecord(items=frozenset({'tidbits', 'specialty chocolate', 'cat food'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tidbits', 'specialty chocolate'}), items_add=frozenset({'cat food'}), confidence=1.0, lift=4.6967741935483875)]),
#  RelationRecord(items=frozenset({'cereals', 'chewing gum', 'cling film/bags'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'cling film/bags'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'detergent', 'cereals', 'flour'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'flour'}), items_add=frozenset({'detergent'}), confidence=0.8333333333333333, lift=5.098039215686274)]),
#  RelationRecord(items=frozenset({'detergent', 'cereals', 'soft cheese'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'soft cheese'}), items_add=frozenset({'detergent'}), confidence=0.875, lift=5.352941176470588)]),
#  RelationRecord(items=frozenset({'cereals', 'mustard', 'hard cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'mustard'}), items_add=frozenset({'hard cheese'}), confidence=0.8, lift=3.1481081081081084)]),
#  RelationRecord(items=frozenset({'cereals', 'waffles', 'mayonnaise'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'mayonnaise'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'cereals', 'mustard', 'sliced cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals', 'mustard'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'chewing gum', 'meat', 'cookware'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat', 'cookware'}), items_add=frozenset({'chewing gum'}), confidence=0.8333333333333333, lift=3.7218813905930466)]),
#  RelationRecord(items=frozenset({'flower soil/fertilizer', 'chewing gum', 'curd'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flower soil/fertilizer', 'curd'}), items_add=frozenset({'chewing gum'}), confidence=0.7142857142857142, lift=3.190184049079754)]),
#  RelationRecord(items=frozenset({'dental care', 'chewing gum', 'grapes'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'dental care', 'chewing gum'}), items_add=frozenset({'grapes'}), confidence=0.8, lift=3.2719101123595506)]),
#  RelationRecord(items=frozenset({'liqueur', 'chewing gum', 'frankfurter'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liqueur', 'frankfurter'}), items_add=frozenset({'chewing gum'}), confidence=1.0, lift=4.466257668711656)]),
#  RelationRecord(items=frozenset({'frozen dessert', 'chewing gum', 'specialty fat'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen dessert', 'specialty fat'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'chewing gum', 'pickled vegetables', 'rum'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pickled vegetables', 'rum'}), items_add=frozenset({'chewing gum'}), confidence=0.8, lift=3.5730061349693254)]),
#  RelationRecord(items=frozenset({'chewing gum', 'specialty bar', 'skin care'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chewing gum', 'skin care'}), items_add=frozenset({'specialty bar'}), confidence=0.8333333333333333, lift=3.2971014492753623), OrderedStatistic(items_base=frozenset({'specialty bar', 'skin care'}), items_add=frozenset({'chewing gum'}), confidence=0.7142857142857142, lift=3.190184049079754)]),
# ...
#  RelationRecord(items=frozenset({'misc. beverages', 'potato products', 'ice cream'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'potato products', 'ice cream'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'potato products', 'specialty bar', 'ice cream'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'potato products', 'ice cream'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'vinegar', 'zwieback', 'ice cream'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'vinegar', 'zwieback'}), items_add=frozenset({'ice cream'}), confidence=1.0, lift=3.5169082125603865)]),
#  RelationRecord(items=frozenset({'liver loaf', 'sliced cheese', 'instant coffee'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liver loaf', 'instant coffee'}), items_add=frozenset({'sliced cheese'}), confidence=1.0, lift=3.9139784946236564)]),
#  RelationRecord(items=frozenset({'instant coffee', 'pot plants', 'oil'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'instant coffee', 'pot plants'}), items_add=frozenset({'oil'}), confidence=0.8571428571428571, lift=3.1999999999999997)]),
#  RelationRecord(items=frozenset({'salty snack', 'instant coffee', 'vinegar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'vinegar', 'instant coffee'}), items_add=frozenset({'salty snack'}), confidence=1.0, lift=3.1790393013100435)]),
#  RelationRecord(items=frozenset({'light bulbs', 'mustard', 'soft cheese'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'mustard'}), items_add=frozenset({'soft cheese'}), confidence=1.0, lift=5.126760563380282)]),
#  RelationRecord(items=frozenset({'light bulbs', 'roll products ', 'sugar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs', 'roll products '}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'liqueur', 'whipped/sour cream', 'pickled vegetables'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liqueur', 'whipped/sour cream'}), items_add=frozenset({'pickled vegetables'}), confidence=0.8333333333333333, lift=5.013774104683195)]),
#  RelationRecord(items=frozenset({'liqueur', 'processed cheese', 'waffles'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liqueur', 'processed cheese'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195), OrderedStatistic(items_base=frozenset({'liqueur', 'waffles'}), items_add=frozenset({'processed cheese'}), confidence=0.8, lift=4.189928057553957)]),
#  RelationRecord(items=frozenset({'liquor (appetizer)', 'male cosmetics', 'meat'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liquor (appetizer)', 'male cosmetics'}), items_add=frozenset({'meat'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'liver loaf', 'processed cheese', 'vinegar'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liver loaf', 'vinegar'}), items_add=frozenset({'processed cheese'}), confidence=0.8, lift=4.189928057553957)]),
#  RelationRecord(items=frozenset({'organic products', 'sugar', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic products', 'long life bakery product'}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'rice', 'sweet spreads', 'long life bakery product'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sweet spreads', 'rice'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'seasonal products', 'tidbits', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'seasonal products', 'tidbits'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'tidbits', 'specialty chocolate', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tidbits', 'specialty chocolate'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'vinegar', 'zwieback', 'long life bakery product'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'vinegar', 'zwieback'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'make up remover', 'pip fruit', 'margarine'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'make up remover'}), items_add=frozenset({'pip fruit', 'margarine'}), confidence=1.0, lift=3.294117647058824)]),
#  RelationRecord(items=frozenset({'seasonal products', 'mayonnaise', 'male cosmetics'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mayonnaise', 'male cosmetics'}), items_add=frozenset({'seasonal products'}), confidence=0.8, lift=5.709803921568628)]),
#  RelationRecord(items=frozenset({'pot plants', 'male cosmetics', 'waffles'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pot plants', 'male cosmetics'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'margarine', 'pudding powder'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'margarine', 'pudding powder'}), items_add=frozenset({'sliced cheese'}), confidence=0.8571428571428571, lift=3.3548387096774195)]),
#  RelationRecord(items=frozenset({'mayonnaise', 'meat spreads', 'sliced cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mayonnaise', 'meat spreads'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'seasonal products', 'meat spreads', 'sliced cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'seasonal products', 'meat spreads'}), items_add=frozenset({'sliced cheese'}), confidence=1.0, lift=3.9139784946236564)]),
#  RelationRecord(items=frozenset({'ready soups', 'misc. beverages', 'onions'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ready soups', 'onions'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'whisky', 'pastry'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pastry', 'whisky'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'pot plants', 'sparkling wine'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pot plants', 'sparkling wine'}), items_add=frozenset({'misc. beverages'}), confidence=1.0, lift=3.8930481283422465)]),
#  RelationRecord(items=frozenset({'roll products ', 'misc. beverages', 'specialty fat'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'roll products ', 'specialty fat'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'misc. beverages', 'whipped/sour cream', 'salad dressing'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'salad dressing'}), items_add=frozenset({'misc. beverages'}), confidence=0.8, lift=3.114438502673797)]),
#  RelationRecord(items=frozenset({'vinegar', 'misc. beverages', 'zwieback'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'vinegar', 'zwieback'}), items_add=frozenset({'misc. beverages'}), confidence=1.0, lift=3.8930481283422465)]),
#  RelationRecord(items=frozenset({'other vegetables', 'salad dressing', 'oil'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'oil', 'other vegetables'}), confidence=0.8333333333333333, lift=3.37037037037037), OrderedStatistic(items_base=frozenset({'salad dressing', 'other vegetables'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'rolls/buns', 'salad dressing', 'oil'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'rolls/buns', 'oil'}), confidence=0.8333333333333333, lift=3.4082397003745317), OrderedStatistic(items_base=frozenset({'rolls/buns', 'salad dressing'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'salad dressing', 'root vegetables', 'oil'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'root vegetables', 'oil'}), confidence=0.8333333333333333, lift=3.991228070175438), OrderedStatistic(items_base=frozenset({'salad dressing', 'root vegetables'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'specialty bar', 'oil', 'rum'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil', 'rum'}), items_add=frozenset({'specialty bar'}), confidence=1.0, lift=3.956521739130435)]),
#  RelationRecord(items=frozenset({'salad dressing', 'oil', 'whole milk'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'oil', 'whole milk'}), confidence=0.8333333333333333, lift=3.2269503546099285), OrderedStatistic(items_base=frozenset({'salad dressing', 'whole milk'}), items_add=frozenset({'oil'}), confidence=0.8333333333333333, lift=3.1111111111111107)]),
#  RelationRecord(items=frozenset({'spices', 'onions', 'white wine'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spices', 'onions'}), items_add=frozenset({'white wine'}), confidence=0.7142857142857142, lift=3.3121019108280247)]),
#  RelationRecord(items=frozenset({'packaged fruit/vegetables', 'soft cheese', 'soap'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'packaged fruit/vegetables', 'soap'}), items_add=frozenset({'soft cheese'}), confidence=0.8, lift=4.101408450704225), OrderedStatistic(items_base=frozenset({'soft cheese', 'soap'}), items_add=frozenset({'packaged fruit/vegetables'}), confidence=0.8, lift=4.6592)]),
#  RelationRecord(items=frozenset({'popcorn', 'pot plants', 'soft cheese'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'popcorn', 'pot plants'}), items_add=frozenset({'soft cheese'}), confidence=0.7142857142857142, lift=3.661971830985915)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'pot plants', 'tidbits'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tidbits', 'pot plants'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'roll products ', 'processed cheese', 'snack products'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese', 'snack products'}), items_add=frozenset({'roll products '}), confidence=0.7142857142857142, lift=6.753246753246753), OrderedStatistic(items_base=frozenset({'roll products ', 'snack products'}), items_add=frozenset({'processed cheese'}), confidence=0.7142857142857142, lift=3.741007194244604)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'specialty chocolate', 'pudding powder'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate', 'pudding powder'}), items_add=frozenset({'sliced cheese'}), confidence=1.0, lift=3.9139784946236564)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'white bread', 'pudding powder'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'white bread', 'pudding powder'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'seasonal products', 'red/blush wine', 'vinegar'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'seasonal products', 'vinegar'}), items_add=frozenset({'red/blush wine'}), confidence=0.7142857142857142, lift=3.687943262411347)]),
#  RelationRecord(items=frozenset({'tidbits', 'specialty cheese', 'red/blush wine'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tidbits', 'specialty cheese'}), items_add=frozenset({'red/blush wine'}), confidence=1.0, lift=5.163120567375886)]),
#  RelationRecord(items=frozenset({'salty snack', 'specialty bar', 'rum'}), support=0.009615384615384616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salty snack', 'rum'}), items_add=frozenset({'specialty bar'}), confidence=0.875, lift=3.4619565217391304)]),
#  RelationRecord(items=frozenset({'salty snack', 'vinegar', 'softener'}), support=0.006868131868131868, ordered_statistics=[OrderedStatistic(items_base=frozenset({'vinegar', 'softener'}), items_add=frozenset({'salty snack'}), confidence=1.0, lift=3.1790393013100435)]),
#  RelationRecord(items=frozenset({'seasonal products', 'sliced cheese', 'zwieback'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'seasonal products', 'zwieback'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'syrup', 'specialty chocolate'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'syrup', 'specialty chocolate'}), items_add=frozenset({'sliced cheese'}), confidence=0.8, lift=3.1311827956989253)]),
#  RelationRecord(items=frozenset({'sugar', 'soft cheese', 'specialty fat'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soft cheese', 'specialty fat'}), items_add=frozenset({'sugar'}), confidence=1.0, lift=3.3703703703703702)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'sparkling wine', 'white wine'}), support=0.008241758241758242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate', 'sparkling wine'}), items_add=frozenset({'white wine'}), confidence=0.8571428571428571, lift=3.97452229299363)]),
#  RelationRecord(items=frozenset({'spices', 'specialty bar', 'spread cheese'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spices', 'spread cheese'}), items_add=frozenset({'specialty bar'}), confidence=0.8, lift=3.165217391304348)]),
#  RelationRecord(items=frozenset({'tidbits', 'waffles', 'zwieback'}), support=0.005494505494505495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tidbits', 'zwieback'}), items_add=frozenset({'waffles'}), confidence=1.0, lift=3.3548387096774195)])]

# %%
len(results)
# Out:
# 379

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
resultsinDataFrame.head()
# Out:
#              Left Hand Side      Right Hand Side   Support  Confidence  \
# 0            salad dressing                  oil  0.006868    0.833333
# 1  female sanitary products  semi-finished bread  0.005495    0.800000
# 2                   mustard                 salt  0.005495    0.800000
# 3     Instant food products   pickled vegetables  0.005495    0.800000
# 4     Instant food products        sliced cheese  0.005495    0.800000
#
#        Lift
# 0  3.111111
# 1  4.585827
# 2  7.372152
# 3  4.813223
# 4  3.131183

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#          Left Hand Side         Right Hand Side   Support  Confidence  \
# 97             cake bar  frozen potato products  0.005495    0.800000
# 36          light bulbs         cling film/bags  0.005495    0.800000
# 105      sparkling wine        specialty cheese  0.005495    0.800000
# 211  pickled vegetables           spread cheese  0.005495    1.000000
# 2               mustard                    salt  0.005495    0.800000
# 366    processed cheese          roll products   0.006868    0.714286
# 35            chocolate           baking powder  0.005495    1.000000
# 37                 curd           baking powder  0.005495    1.000000
# 40                herbs           baking powder  0.005495    1.000000
# 191         hard cheese              pot plants  0.005495    1.000000
#
#          Lift
# 97   8.692537
# 36   8.320000
# 105  8.320000
# 211  7.663158
# 2    7.372152
# 366  6.753247
# 35   6.618182
# 37   6.618182
# 40   6.618182
# 191  6.385965
